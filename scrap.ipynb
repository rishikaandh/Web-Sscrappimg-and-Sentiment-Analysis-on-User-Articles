# %%
import requests
import os
import selenium
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import TimeoutException

# %%
def extract_article_text_selenium(url, driver):
    try:
        #Open the URL
        driver.get(url)
        driver.implicitly_wait(10)
        #Get the page source
        page_source = driver.page_source

        #parse the HTML content
        soup = BeautifulSoup(page_source, 'html.parser')

        paragraphs = soup.find_all('p')

        article_text = '\n'.join([paragraph.get_text() for paragraph in paragraphs])

        return article_text
    except Exception as e:
        print(f"Error extracting article text: {str(e)}")
        return None

def scrape_and_save_selenium(input_file_path, output_folder_path, chrome_driver_path):
    #Set up Chrome options
    chrome_options = Options()
    chrome_options.add_argument('--headless')
    #Set up the Chrome service
    service = ChromeService(chrome_driver_path)
    driver = webdriver.Chrome(service=service, options=chrome_options)
    driver.set_page_load_timeout(30)  # Set a timeout of 30 seconds (adjust as needed)

    df = pd.read_excel(input_file_path)

    for index, row in df.iterrows():
        url_id = row['URL_ID']
        url = row['URL']

        try:
            article_text = extract_article_text_selenium(url, driver)

            if article_text:
                # Create a folder with the URL_ID if it doesn't exist
                folder_path = os.path.join(output_folder_path, f"{url_id}")
                os.makedirs(folder_path, exist_ok=True)

                with open(os.path.join(folder_path, f"{url_id}.txt"), "w", encoding="utf-8") as file:
                    file.write(article_text)

                print(f"Scraping completed for URL_ID: {url_id}")
            else:
                print(f"Skipping URL_ID {url_id} due to extraction error.")
        except TimeoutException:
            print(f"Timeout while loading the page: {url}")
        except Exception as e:
            print(f"Error scraping URL_ID {url_id}: {str(e)}")

    driver.quit()

# %%
output_folder_path=("D:\internship\output")
chrome_driver_path=("D:\internship\chromedriver.exe")
input_file_path = ("Input.xlsx")

# %%
scrape_and_save_selenium(input_file_path, output_folder_path, chrome_driver_path)
# Out:
# Scraping completed for URL_ID: blackassign0001
# Scraping completed for URL_ID: blackassign0002
# Scraping completed for URL_ID: blackassign0003
# Scraping completed for URL_ID: blackassign0004
# Scraping completed for URL_ID: blackassign0005
# Scraping completed for URL_ID: blackassign0006
# Scraping completed for URL_ID: blackassign0007
# Scraping completed for URL_ID: blackassign0008
# Scraping completed for URL_ID: blackassign0009
# Scraping completed for URL_ID: blackassign0010
# Scraping completed for URL_ID: blackassign0011
# Scraping completed for URL_ID: blackassign0012
# Scraping completed for URL_ID: blackassign0013
# Scraping completed for URL_ID: blackassign0014
# Scraping completed for URL_ID: blackassign0015
# Scraping completed for URL_ID: blackassign0016
# Scraping completed for URL_ID: blackassign0017
# Scraping completed for URL_ID: blackassign0018
# Scraping completed for URL_ID: blackassign0019
# Scraping completed for URL_ID: blackassign0020
# Scraping completed for URL_ID: blackassign0021
# Scraping completed for URL_ID: blackassign0022
# Scraping completed for URL_ID: blackassign0023
# Scraping completed for URL_ID: blackassign0024
# Scraping completed for URL_ID: blackassign0025
# Scraping completed for URL_ID: blackassign0026
# Scraping completed for URL_ID: blackassign0027
# Scraping completed for URL_ID: blackassign0028
# Scraping completed for URL_ID: blackassign0029
# Scraping completed for URL_ID: blackassign0030
# Scraping completed for URL_ID: blackassign0031
# Scraping completed for URL_ID: blackassign0032
# Scraping completed for URL_ID: blackassign0033
# Scraping completed for URL_ID: blackassign0034
# Scraping completed for URL_ID: blackassign0035
# Scraping completed for URL_ID: blackassign0036
# Scraping completed for URL_ID: blackassign0037
# Scraping completed for URL_ID: blackassign0038
# Scraping completed for URL_ID: blackassign0039
# Scraping completed for URL_ID: blackassign0040
# Scraping completed for URL_ID: blackassign0041
# Scraping completed for URL_ID: blackassign0042
# Scraping completed for URL_ID: blackassign0043
# Scraping completed for URL_ID: blackassign0044
# Scraping completed for URL_ID: blackassign0045
# Scraping completed for URL_ID: blackassign0046
# Scraping completed for URL_ID: blackassign0047
# Scraping completed for URL_ID: blackassign0048
# Scraping completed for URL_ID: blackassign0049
# Scraping completed for URL_ID: blackassign0050
# Scraping completed for URL_ID: blackassign0051
# Scraping completed for URL_ID: blackassign0052
# Scraping completed for URL_ID: blackassign0053
# Scraping completed for URL_ID: blackassign0054
# Scraping completed for URL_ID: blackassign0055
# Scraping completed for URL_ID: blackassign0056
# Scraping completed for URL_ID: blackassign0057
# Scraping completed for URL_ID: blackassign0058
# Scraping completed for URL_ID: blackassign0059
# Scraping completed for URL_ID: blackassign0060
# Scraping completed for URL_ID: blackassign0061
# Scraping completed for URL_ID: blackassign0062
# Scraping completed for URL_ID: blackassign0063
# Scraping completed for URL_ID: blackassign0064
# Scraping completed for URL_ID: blackassign0065
# Scraping completed for URL_ID: blackassign0066
# Scraping completed for URL_ID: blackassign0067
# Scraping completed for URL_ID: blackassign0068
# Scraping completed for URL_ID: blackassign0069
# Scraping completed for URL_ID: blackassign0070
# Scraping completed for URL_ID: blackassign0071
# Scraping completed for URL_ID: blackassign0072
# Scraping completed for URL_ID: blackassign0073
# Scraping completed for URL_ID: blackassign0074
# Scraping completed for URL_ID: blackassign0075
# Scraping completed for URL_ID: blackassign0076
# Scraping completed for URL_ID: blackassign0077
# Scraping completed for URL_ID: blackassign0078
# Scraping completed for URL_ID: blackassign0079
# Scraping completed for URL_ID: blackassign0080
# Scraping completed for URL_ID: blackassign0081
# Scraping completed for URL_ID: blackassign0082
# Scraping completed for URL_ID: blackassign0083
# Scraping completed for URL_ID: blackassign0084
# Scraping completed for URL_ID: blackassign0085
# Scraping completed for URL_ID: blackassign0086
# Scraping completed for URL_ID: blackassign0087
# Scraping completed for URL_ID: blackassign0088
# Scraping completed for URL_ID: blackassign0089
# Scraping completed for URL_ID: blackassign0090
# Scraping completed for URL_ID: blackassign0091
# Scraping completed for URL_ID: blackassign0092
# Scraping completed for URL_ID: blackassign0093
# Scraping completed for URL_ID: blackassign0094
# Scraping completed for URL_ID: blackassign0095
# Scraping completed for URL_ID: blackassign0096
# Scraping completed for URL_ID: blackassign0097
# Scraping completed for URL_ID: blackassign0098
# Scraping completed for URL_ID: blackassign0099
# Scraping completed for URL_ID: blackassign0100

# %%
stopwords_file_path = r"D:\internship\StopWords\StopWords_Auditor.txt"

def read_stopwords_from_file(stopwords_file_path):
    with open(stopwords_file_path, 'r', encoding='latin-1') as file:
        stopwords_lines = file.readlines()
    stop_words = [line.strip() for line in stopwords_lines]
    return set(stop_words)

stop_words = read_stopwords_from_file(stopwords_file_path)

print("Stop Words:")
a=(stop_words)
print(a)
# Out:
# Stop Words:
# {'YOUNG', 'TOUCHE', 'PRICEWATERHOUSECOOPERS', 'KPMG', 'COOPERS', 'PRICEWATERHOUSE', 'ERNST', 'DELOITTE'}

# %%
stopwords_file_path = r"D:\internship\StopWords\StopWords_Generic.txt"

def read_stopwords_from_file(stopwords_file_path):
    with open(stopwords_file_path, 'r', encoding='latin-1') as file:
        stopwords_lines = file.readlines()
    stop_words = [line.strip() for line in stopwords_lines]
    return set(stop_words)

stop_words = read_stopwords_from_file(stopwords_file_path)

print("Stop Words:")
b=(stop_words)
print(b)
# Out:
# Stop Words:
# {'ON', 'WHICH', 'HAVING', 'WE', 'AT', 'HAVE', 'ONLY', 'THERE', 'HAD', 'AGAIN', 'HIS', 'THE', 'IS', 'WHERE', 'MOST', 'HERSELF', 'THEY', 'ABOUT', 'SAME', 'DOING', 'VERY', 'NO', 'HER', 'ARE', 'WITH', 'HAS', 'AS', 'INTO', 'NOR', 'ITS', 'WHAT', 'OVER', 'WAS', 'THEIRS', 'WHILE', 'FROM', 'TOO', 'ONCE', 'YOURSELF', 'UP', 'UNTIL', 'ITSELF', 'OUT', 'SHOULD', 'IN', 'THEM', 'MY', 'THEMSELVES', 'BUT', 'OWN', 'ANY', 'AFTER', 'OF', 'BELOW', 'YOURS', 'CAN', 'FEW', 'OURS', 'EACH', 'SHE', 'OTHER', 'THEN', 'WHOM', 'ME', 'AN', 'SO', 'IF', 'SOME', 'THESE', 'THOSE', 'OR', 'WHY', 'ALL', 'DID', 'BOTH', 'IT', 'NOW', 'THAT', 'YOU', 'FURTHER', 'DOES', 'BY', 'MYSELF', 'MORE', 'HE', 'BECAUSE', 'ABOVE', 'THAN', 'OFF', 'DOWN', 'HIMSELF', 'OURSELVES', 'DO', 'DURING', 'SUCH', 'YOUR', 'BE', 'HIM', 'UNDER', 'HERS', 'BEING', 'HERE', 'AM', 'BEFORE', 'THROUGH', 'HOW', 'NOT', 'AMONG', 'WHEN', 'WHO', 'THIS', 'THEIR', 'TO', 'AND', 'YOURSELVES', 'JUST', 'WERE', 'FOR', 'OUR', 'BEEN', 'BETWEEN'}

# %%
stopwords_file_path = r"D:\internship\StopWords\StopWords_GenericLong.txt"

def read_stopwords_from_file(stopwords_file_path):
    with open(stopwords_file_path, 'r', encoding='latin-1') as file:
        stopwords_lines = file.readlines()
    stop_words = [line.strip() for line in stopwords_lines]
    return set(stop_words)

stop_words = read_stopwords_from_file(stopwords_file_path)

print("Stop Words:")
c=(stop_words)
print(c)
# Out:
# Stop Words:
# {'keep', 'ones', 'wonder', 'oh', 'accordingly', 'becomes', 'downwards', 'happens', 'through', 'ltd', 'perhaps', 'was', 'namely', 'u', 'only', 'believe', 'how', 'saying', 'un', 'are', 'further', 'mean', 'both', 'whereupon', 'w', 'when', 'clearly', 'relatively', "they'd", 'what', "they've", 'x', 'getting', 'new', 'etc', 'taken', 'upon', 'had', 'hers', 'particularly', 'his', "isn't", 'appreciate', 'really', 'there', 'towards', 'concerning', "i'd", 'ex', 'definitely', 'sometime', 'said', 'thanx', "we're", 'whence', 'g', "doesn't", 'want', "c's", 'contains', 'eg', 'yours', 'look', 'on', "a's", 'o', 'else', 'beyond', 'having', 'where', 'exactly', 'although', 'uucp', 'indicated', 'cannot', 'sent', 'according', 'former', 'specifying', 'onto', 'go', 'que', 'follows', 'entirely', 'they', 'p', 'zero', 'apart', 'therein', 'nevertheless', 'seemed', 'consider', 'necessary', 'another', 'third', 'tends', 'the', 'while', 'goes', "they're", 'into', 'often', 'somewhat', 'went', 'least', 'besides', 'twice', 'likely', 'across', 'have', 'here', 'it', 'became', 'example', 'my', 'someone', 'com', "weren't", 'nobody', 'along', 'each', 'ours', 'thereby', 'certain', "c'mon", 'fifth', 'wish', 'nine', "it's", 'help', 'nd', 'since', 'sorry', 'inward', 'thereafter', 'does', 'herein', 'contain', 'already', 'well', 'over', 'ought', 'sometimes', 'sub', 'viz', 'given', 'nowhere', 'think', 'your', 'thorough', 'never', 'plus', 'everywhere', 'come', 'probably', 'known', 'seriously', 'trying', 'doing', "hadn't", 'lately', 'going', 'formerly', 'himself', "you'll", 'off', 'together', 'take', 'willing', "where's", 'anyways', 'to', 'later', 'between', 'against', 'name', 'behind', 'among', 'still', 'this', 'which', 'latterly', 'me', "you'd", 'whose', 'second', 'away', 'vs', 'seeing', 'yourselves', 'everything', 'needs', 'v', 'thanks', 'cant', 'ie', 'whatever', 'without', 'anywhere', 'us', 'obviously', 'l', 'therefore', 'seem', "what's", 'many', 'her', 's', 'different', 'would', 'f', "we'd", 'gets', 'throughout', 'et', 'gives', 'inasmuch', 'co', 'changes', 'all', 'various', "we'll", 'please', 'via', 'about', 'especially', 'able', 'is', 'need', 'no', "i've", 'got', 'usually', 'followed', 'these', 'wherein', "won't", 'you', 'once', 'like', 'four', 'wherever', 'anything', 'done', 'however', 'inner', 'one', 'thats', 'become', 'do', 'whom', 'after', 'whoever', 'okay', "i'm", 'instead', 'hello', 'of', 't', 'may', 'normally', 'selves', 'otherwise', 'very', 'little', 'than', 'awfully', 'unto', 'hardly', 'three', 'either', 'them', 'afterwards', 'came', 'immediate', 'cause', 'beforehand', 'described', 'everybody', 'ok', 'again', 'anyhow', 'useful', "that's", 'seems', 'value', 'keeps', 'why', 'for', 'becoming', 'five', "let's", 'serious', 'regarding', 'anybody', 'almost', 'by', "hasn't", 'yes', 'meanwhile', 'with', 'let', "i'll", 'old', 'will', 'edu', 'actually', 'truly', 'indicate', 'hi', 'rd', 'h', 'course', 'our', 'few', 'more', 'knows', 'better', 'q', "who's", 'seeming', 'see', 'causes', 'says', 'yourself', 'unless', 'if', 'who', 'others', 'myself', "don't", "they'll", 'secondly', "ain't", 'regardless', "couldn't", 'hereafter', 'nearly', 'sensible', 'whither', 'except', 'right', 'thus', 'theirs', 'hence', 'looks', 'b', 'some', 'used', 'latter', 'such', "t's", 'whether', "he's", 'beside', 'last', 'unlikely', 'allows', 'none', 'regards', 'self', 'their', 'thence', 'mostly', 'furthermore', 'liked', 'consequently', 'possible', 'amongst', 'should', 'might', 'within', 'uses', 'allow', 'but', 'comes', 'or', 'elsewhere', 'hereby', "shouldn't", 'quite', 'anyway', 'thoroughly', 'wants', 'y', 'indeed', 'lest', 'hopefully', 'down', 'at', 'he', 'merely', 'did', 'nothing', "can't", 'and', 'she', "here's", 'z', 'those', 'own', 'inc', 'six', 'most', 'took', 'am', 'appropriate', 'thereupon', 'shall', 'too', 'always', 'being', 'thank', 'its', 'currently', 'asking', 'every', 'get', 'per', 'greetings', 'available', 'up', 'could', "didn't", 'around', 'something', "wouldn't", 'first', 'ask', 'be', ' ...

# %% [markdown]
# **for stop words which were in WORD | Category**

# %%
stopwords_file_path = r"D:\internship\StopWords\StopWords_Currencies.txt"

def read_stopwords_from_file(stopwords_file_path):
    with open(stopwords_file_path, 'r', encoding='latin-1') as file:
        stopwords_lines = file.readlines()
    stop_words = [line.split('|')[0].strip() for line in stopwords_lines]
    return set(stop_words)

stop_words = read_stopwords_from_file(stopwords_file_path)

print("Stop Words:")
d=(stop_words)
print(d)
# Out:
# Stop Words:
# {'FLORIN', 'LIRA', 'LOTI', 'KINA', 'KUNA', 'NGULTRUM', 'PATACA', 'DIRHAM', 'DINAR', 'GULDEN', 'DENAR', 'POUND', 'BOLIVAR', 'KIP', 'KROON', 'CÓRDOBA', 'MANAT', 'BALBOA', 'KRONA', 'TAKA', 'TALA', 'RIEL', 'METICAL', 'NAIRA', 'BOLIVIANO', 'SOMONI', 'SHILLING', 'BAHT', 'BIRR', 'RENMINBI', 'DONG', 'NUEVO SOL', 'RAND', 'ARIARY', 'GOURDE', 'LEONE', 'DOBRA', 'FORINT', 'NAKFA', 'KRONE', 'PESO', 'LEK', 'LATS', 'OUGUIYA', 'KORUNA', 'RUPIAH', 'PULA', 'RIYAL', 'EURO', 'DALASI', 'KWANZA', 'REAL', 'TUGRIK', 'LEMPIRA', 'RINGGIT', 'SOM', 'RUPEE', 'YEN', 'KYAT', 'HRYVNIA', 'RUFIYAA', 'LITAS', 'LEU', 'LARI', 'QUETZAL', 'WON', 'KWACHA', 'GUARANI', 'SPECIAL DRAWING RIGHTS', 'TENGE', 'COLON', 'KONVERTIBILNA MARKA', 'NEW LIRA', 'CEDI', 'ESCUDO', 'AFGHANI', 'VATU', 'DRAM', 'LILANGENI', 'RIAL', 'RUBLE', 'NEW SHEQEL', 'LEV', 'ZLOTY'}

# %% [markdown]
# **for stop words which were in WORD | Category form as well as normal words**

# %%
stopwords_file_path = r"D:\internship\StopWords\StopWords_DatesandNumbers.txt"
def read_stopwords_from_file(stopwords_file_path):
    with open(stopwords_file_path, 'r', encoding='latin-1') as file:
        stopwords_lines = file.readlines()
    stop_words = set()
    for line in stopwords_lines:
        parts = line.split('|')
        
        if len(parts) > 1:
            word = parts[0].strip()
            stop_words.add(word)
        else:
            word = line.strip()
            stop_words.add(word)

    return stop_words

stop_words = read_stopwords_from_file(stopwords_file_path)

print("Stop Words:")
e=(stop_words)
print(e)
# Out:
# Stop Words:
# {'II', 'NOV', 'JUN', 'NINTH', 'FOUR', 'HUNDRED', 'WEEK', 'TRILLION', 'APRIL', 'SIXTEEN', 'NOVEMBER', 'DAILY', 'QUARTERLY', 'XI', 'SEVENTH', 'X', 'YEARLY', 'OCTOBER', 'SUNDAY', 'I', 'FIFTY', 'IV', 'JULY', 'MARCH', 'TWO', 'MAR', 'WEEKLY', 'XVI', 'AUG', 'JAN', 'XX', 'SEPTEMBER', 'MONDAY', 'MONTH', 'FORTY', 'ANNUM', 'EIGHTH', 'THREE', 'JUL', 'DECEMBER', 'XVIII', 'FIFTH', 'XIX', 'SEVENTY', 'FIRST', 'III', 'OCT', 'SEVEN', 'THOUSAND', 'TWENTY', 'NINE', 'ONE', 'EIGHTY', 'TWELVE', 'FRIDAY', 'FEBRUARY', 'YEAR', 'SIXTY', 'TEN', 'FIFTEEN', 'NINETY', 'TENTH', 'THIRTY', 'IX', 'MAY', 'FOURTH', 'SATURDAY', 'JUNE', 'XII', 'ANNUAL', 'SIX', 'XIII', 'SEVENTEEN', 'VII', 'SEPT', 'QUARTER', 'WEDNESDAY', 'AUGUST', 'FIVE', 'V', 'XV', 'VI', 'NINETEEN', 'EIGHTEEN', 'SIXTH', 'THIRTEEN', 'JANUARY', 'SECOND', 'DATE', 'SEP', 'ANNUALLY', 'TUESDAY', 'XIV', 'THIRD', 'VIII', 'FOURTEEN', 'XVII', 'DEC', 'THURSDAY', 'MILLION', 'APR', 'BILLION', 'MONTHLY', 'FEB', 'ELEVEN', 'QTR', 'EIGHT', 'DAY'}

# %%
stopwords_file_path = r"D:\internship\StopWords\StopWords_Geographic.txt"
def read_stopwords_from_file(stopwords_file_path):
    with open(stopwords_file_path, 'r', encoding='latin-1') as file:
        stopwords_lines = file.readlines()
    stop_words = set()
    for line in stopwords_lines:
        parts = line.split('|')
        if len(parts) > 1:
            word = parts[0].strip()
            stop_words.add(word)
        else:
            word = line.strip()
            stop_words.add(word)

    return stop_words

stop_words = read_stopwords_from_file(stopwords_file_path)

print("Stop Words:")
f=(stop_words)
print(f)
# Out:
# Stop Words:
# {'WEST', 'NORTHEAST', 'ANGELES', 'SOUTHEAST', 'KARACHI', 'BANGLADESH', 'MEXICO', 'ISLAND', 'VIRGINIA', 'IDAHO', 'DETROIT', 'MEXICAN', 'COLUMBUS', 'DENMARK', 'ILLINOIS', 'NOVA', 'STATE', 'IOWA', 'FLORIDA', 'OREGON', 'SOUTHWEST', 'GERMANY', 'KOREA', 'SEA', 'SAO', 'SWITZERLAND', 'INDIANA', 'DALLAS', 'ALASKA', 'MUMBAI', 'SUISSE', 'BELGIUM', 'CZECK', 'TAIWAN', 'LUXEMBOURG', 'CHINA', 'DAKOTA', 'MINNEAPOLIS', 'VIETNAM', 'NIGERIA', 'COLUMBIA', 'TURKEY', 'MONTANA', 'DELHI', 'MISSOURI', 'MALAYSIA', 'ATLANTA', 'NETHERLANDS', 'BLVD', 'OHIO', 'LOUIS', 'LAKE', 'CHICAGO', 'HOLLYWOOD', 'SINGAPORE', 'ARIZONA', 'CALIFORNIA', 'FRANSICO', 'MANHATTAN', 'RICA', 'PHILIPPINES', 'ASIA', 'DIEGO', 'MEMPHIS', 'RIVER', 'PITTSBURGH', 'FRANCE', 'EUROPEAN', 'HOUSTON', 'BEIJING', 'HAMPSHIRE', 'WISCONSIN', 'OKLAHOMA', 'NEBRASKA', 'ITALIAN', 'PORTUGAL', 'JERSEY', 'YORK', 'STREET', 'VENEZUELA', 'RUSSIA', 'VERMONT', 'PARKWAY', 'MIAMI', 'REPUBLIC', 'CHILEAN', 'JAPANESE', 'BERMUDA', 'TEXAS', 'MEDITERRANEAN', 'SCOTIA', 'CAROLINA', 'ST', 'MASSACHUSETTS', 'BOULEVARD', 'INDONESIA', 'CANADA', 'OCEAN', 'PHOENIX', 'CINCINNATI', 'MICHIGAN', 'PHILADELPHIA', 'CHILE', 'NORWAY', 'EUROPE', 'FINLAND', 'TOKYO', 'CITY', 'UNITED', 'JAKARTA', 'PENNSYLVANIA', 'PAKISTAN', 'POLAND', 'CHINESE', 'GEORGIA', 'MARYLAND', 'TORONTO', 'WASHINGTON', 'SCOTLAND', 'ISTANBUL', 'LOS', 'CREEK', 'TENNESSEE', 'NORTH', 'CAMBRIDGE', 'MOUNTAIN', 'SEATTLE', 'PAULO', 'NORTHWEST', 'ITALY', 'MINNESOTA', 'MISSISSIPPI', 'WYOMING', 'LONDON', 'BRAZILIAN', 'COMMONWEALTH', 'AMERICA', 'COSTA', 'SWISS', 'ARKANSAS', 'BOSTON', 'USA', 'RHODE', 'NEW', 'AMERICAN', 'LOUISIANA', 'SWEDEN', 'DELAWARE', 'MAINE', 'HUNGARY', 'MILWAUKEE', 'PUERTO', 'PACIFIC', 'MOSCOW', 'HAWAII', 'KANSAS', 'EAST', 'LATIN', 'AUSTRIA', 'SEOUL', 'ZEALAND', 'ALABAMA', 'AFRICAN', 'ATLANTIC', 'SHANGHAI', 'ARGENTINA', 'LAS', 'COLORADO', 'FREMONT', 'DENVER', 'AFRICA', 'CONNECTICUT', 'THAILAND', 'KENTUCKY', 'JAPAN', 'SPAIN', 'UTAH', 'INDIAN', 'COUNTY', 'CANADIAN', 'AUSTRALIA', 'INDIA', 'SOUTH', 'ONTARIO', 'SAN', 'BRITISH', 'FORT', 'VEGAS', 'GULF', 'NEVADA', 'INDIANAPOLIS', 'COUNTRY', 'BRAZIL', 'SUNNYVALE'}

# %%
stopwords_file_path = r"D:\internship\StopWords\StopWords_Names.txt"
def read_stopwords_from_file(stopwords_file_path):
    with open(stopwords_file_path, 'r', encoding='latin-1') as file:
        stopwords_lines = file.readlines()
    stop_words = set()

    for line in stopwords_lines:
        parts = line.split('|')
        
        if len(parts) > 1:
            word = parts[0].strip()
            stop_words.add(word)
        else:
            word = line.strip()
            stop_words.add(word)
    return stop_words

stop_words = read_stopwords_from_file(stopwords_file_path)

print("Stop Words:")
g=(stop_words)
print(g)
# Out:
# Stop Words:
# {'KALA', 'OVERTON', 'HENDRIX', 'KHOURY', 'LATOSHA', 'LE', 'BALDERAS', 'RULE', 'JUSTINE', 'MATTHEWS', 'CYR', 'MUNGUIA', 'SHAROLYN', 'BRUNA', 'JOESPH', 'BOLDEN', 'MACKENZIE', 'MCMANUS', 'IVANA', 'PARENT', 'SAMUAL', 'TURNER', 'GERMANY', 'SULLIVAN', 'CORNWELL', 'EARNEST', 'KARINA', 'SNYDER', 'WILMOT', 'YOLONDA', 'HOSTETTER', 'JACOB', 'JABLONSKI', 'MARIANN', 'HERZOG', 'SHUMWAY', 'VICKERY', 'MACHELLE', 'MCLAIN', 'DANYELL', 'JENNIFER', 'HAMILTON', 'AUDRIE', 'KARLEEN', 'BEESON', 'RAYMON', 'DEVILLE', 'LEANORA', 'MARTINE', 'PALMER', 'GILBERTE', 'AMADA', 'LEZLIE', 'KINDER', 'JOLINE', 'LEXIE', 'DOLAN', 'GISELE', 'JACQUIE', 'FELDER', 'BRADBURY', 'CUSHING', 'FORTENBERRY', 'KAILA', 'LAROCHE', 'COWARD', 'MICKELSON', 'RIVA', 'NEGRETE', 'ORELLANA', 'FERNANDA', 'MERISSA', 'WILLOUGHBY', 'ADAMS', 'BELL', 'SNOW', 'TIESHA', 'CARLYN', 'SHEMEKA', 'SETZER', 'BEERY', 'LERNER', 'MINTER', 'ALVES', 'BAUGHER', 'PIERSON', 'MCGILL', 'OTILIA', 'SCANLON', 'BECNEL', 'GODWIN', 'DESANTIS', 'DARIO', 'TASHA', 'CHASSIDY', 'TERRILL', 'TAREN', 'IVELISSE', 'LEYVA', 'ELISABETH', 'LENNOX', 'ZAVALA', 'HARMS', 'SPIVEY', 'HOOPER', 'NADEAU', 'LEMONS', 'BOWLING', 'JAMEL', 'CHERELLE', 'MADIGAN', 'TURNAGE', 'PERRYMAN', 'SHARRON', 'MCNULTY', 'PARISI', 'CLEM', 'SHAD', 'PAEZ', 'MCLAURIN', 'TOTTEN', 'CARRILLO', 'MERCY', 'HERMELINDA', 'WILL', 'SPEER', 'HALPIN', 'RICKIE', 'RIVERS', 'BURNS', 'WHITTEN', 'BLANCHARD', 'MADIE', 'SNODGRASS', 'LAURAN', 'ALSTON', 'SUBLETT', 'PAMELA', 'CATHCART', 'BURTON', 'DIMPLE', 'MARIEL', 'MERTZ', 'WILLIAM', 'BRAXTON', 'GARFIELD', 'BUELL', 'BILLY', 'TERRI', 'TIMIKA', 'PARRY', 'RAMBO', 'ANTHONY', 'ALVERA', 'TERENCE', 'OMALLEY', 'LUNDQUIST', 'ALDA', 'XUAN', 'LINA', 'CONCETTA', 'SATTLER', 'PAK', 'HANNELORE', 'COVER', 'BOBETTE', 'ANABEL', 'MCGOUGH', 'BORGES', 'BALCH', 'CLARE', 'HELGA', 'OLIVEIRA', 'DUHON', 'AMERSON', 'QUARLES', 'DOVIE', 'DOOLITTLE', 'NAIDA', 'CARMELA', 'ASA', 'ALCANTARA', 'MENA', 'LANTZ', 'JACINDA', 'NOELLA', 'ANGELL', 'PRECIADO', 'BUMP', 'MARYANN', 'ROUNDY', 'ROYCE', 'ETTA', 'BALLEW', 'CORDES', 'LERA', 'BENAVIDEZ', 'MCNEELY', 'DAINA', 'HUDSPETH', 'HOLM', 'SULLINS', 'HYE', 'CROCKETT', 'ANJANETTE', 'TILLEY', 'SARVER', 'BRUMLEY', 'HENDRICKS', 'ELLINGTON', 'LINEBERRY', 'THAO', 'VOLPE', 'ORTEGO', 'LEOMA', 'LIM', 'MCFARLIN', 'STEEL', 'TROMBLEY', 'RAINA', 'HAWORTH', 'HUNG', 'HUDGINS', 'TERRY', 'SOKOL', 'PROPST', 'MCCLURG', 'ANTONIETTA', 'WARRINGTON', 'POLING', 'JAN', 'FOGARTY', 'BURKHARDT', 'GABRIELA', 'JALEESA', 'SIMONA', 'LOUETTA', 'JEWELL', 'CLAUDIO', 'ISIS', 'LYNCH', 'LEIGHA', 'MONTANO', 'LIA', 'AMELIA', 'BUSTOS', 'LINDGREN', 'GENOVEVA', 'DANTZLER', 'RIDGE', 'ELSIE', 'DOMBROWSKI', 'MIGDALIA', 'DACIA', 'HANLEY', 'COGGINS', 'SOCORRO', 'KIRKWOOD', 'HOULE', 'ELENORE', 'SCHUMACHER', 'PORFIRIO', 'ATHERTON', 'SEWARD', 'SANDI', 'JACKS', 'LEANDRA', 'GARMAN', 'DAGGETT', 'OTELIA', 'ANDRE', 'COLLIER', 'MADELENE', 'DOLLAR', 'GOTT', 'MCGEE', 'DUBE', 'MANSOUR', 'JANNET', 'GREATHOUSE', 'OGRADY', 'RANSOM', 'NYLA', 'MORRISSETTE', 'LEAH', 'JANEY', 'ARNOLD', 'MELBA', 'NEOMI', 'BOLT', 'LARRY', 'SCOGGINS', 'RICKEY', 'GAUDET', 'SIGNE', 'BRUNET', 'MYRTLE', 'BABCOCK', 'LANEY', 'MARQUITTA', 'WRIGHT', 'SIGRID', 'REECE', 'CICELY', 'ROCK', 'RICKER', 'FIELDING', 'RANGE', 'SHORES', 'SUDIE', 'ADELA', 'LOVELL', 'PAZ', 'SORAYA', 'BARNEY', 'LIANNE', 'EASON', 'LANGE', 'HENRY', 'THURBER', 'ADAM', 'LANG', 'STOUT', 'MANZANO', 'WHITTINGTON', 'MEACHAM', 'BRECKENRIDGE', 'NICHOLE', 'KARL', 'BEATON', 'BART', 'ALLEY', 'FELKER', 'VITA', 'VALRIE', 'HUNLEY', 'NOONAN', 'DUNAGAN', 'VANDYKE', 'SOARES', 'ARDOIN', 'BESSIE', 'BAINES', 'REGO', 'BROADNAX', 'DANN', 'KNOWLES', 'HASSELL', 'NUNN', 'NORFLEET', 'HUMBLE', 'DICKENSON', 'GRANT', 'JEANA', 'CHURCH', 'JANEL', 'KAVANAUGH', 'STCLAIR', 'KRISTINA', 'NEVADA', 'WILCHER', 'AGEE', 'HUGHEY', 'PAMALA', 'SOUTHERLAND', 'GUIDO', 'ASHLI', 'KATO', 'BURRELL', 'LOUDERMILK', 'LOREN', 'TABATHA', 'LAMONT', 'DECK', 'JULIANNE', 'LATOYIA', 'LATIA', 'VOIGT', 'MEAGAN', 'LUSK', 'CYRIL', 'BASSETT', 'MING', 'CIRA', 'BUSCH', 'ROSELINE', 'JANNA', 'ROBBIN', 'KAPLAN', 'LAKENDR ...

# %%
combine=a.union(b,c,d,e,f,g)
combine
# Out:
# {'KALA',
#  'OVERTON',
#  'HENDRIX',
#  'KHOURY',
#  'LATOSHA',
#  'LE',
#  'BALDERAS',
#  'RULE',
#  'JUSTINE',
#  'MATTHEWS',
#  'CYR',
#  'MUNGUIA',
#  'SHAROLYN',
#  'BRUNA',
#  'JOESPH',
#  'ltd',
#  'BOLDEN',
#  'MACKENZIE',
#  'MCMANUS',
#  'IVANA',
#  'PARENT',
#  'SAMUAL',
#  'TURNER',
#  'GERMANY',
#  'SULLIVAN',
#  'CORNWELL',
#  'EARNEST',
#  'KARINA',
#  'SNYDER',
#  'WILMOT',
#  'YOLONDA',
#  'HOSTETTER',
#  'JACOB',
#  'JABLONSKI',
#  'MARIANN',
#  'HERZOG',
#  'SHUMWAY',
#  'VICKERY',
#  'MACHELLE',
#  'MCLAIN',
#  'DANYELL',
#  'JENNIFER',
#  'HAMILTON',
#  'AUDRIE',
#  'KARLEEN',
#  'BEESON',
#  'RAYMON',
#  'DEVILLE',
#  'LEANORA',
#  'MARTINE',
#  'PALMER',
#  'GILBERTE',
#  'AMADA',
#  'LEZLIE',
#  'KINDER',
#  'JOLINE',
#  'LEXIE',
#  'DOLAN',
#  'GISELE',
#  'JACQUIE',
#  'FELDER',
#  'BRADBURY',
#  'CUSHING',
#  'FORTENBERRY',
#  'KAILA',
#  'LAROCHE',
#  'COWARD',
#  'MICKELSON',
#  'OKLAHOMA',
#  'RIVA',
#  'NEGRETE',
#  'ORELLANA',
#  'FERNANDA',
#  'MERISSA',
#  'WILLOUGHBY',
#  'ADAMS',
#  'BELL',
#  'SNOW',
#  'TIESHA',
#  'CARLYN',
#  'SHEMEKA',
#  'SETZER',
#  'BEERY',
#  'LERNER',
#  'MINTER',
#  'ALVES',
#  'BAUGHER',
#  'PIERSON',
#  'MCGILL',
#  'OTILIA',
#  'SCANLON',
#  'BECNEL',
#  'GODWIN',
#  'DESANTIS',
#  'DARIO',
#  'TASHA',
#  'CHASSIDY',
#  'TERRILL',
#  'TAREN',
#  'IVELISSE',
#  'LEYVA',
#  'ELISABETH',
#  'LENNOX',
#  'ZAVALA',
#  'HARMS',
#  'SPIVEY',
#  'HOOPER',
#  'NADEAU',
#  'LEMONS',
#  'BOWLING',
#  'JAMEL',
#  'CHERELLE',
#  'MADIGAN',
#  'TURNAGE',
#  'PERRYMAN',
#  'SHARRON',
#  'MCNULTY',
#  'PARISI',
#  'CLEM',
#  'SHAD',
#  'PAEZ',
#  'MCLAURIN',
#  'TOTTEN',
#  'CARRILLO',
#  'MERCY',
#  'HERMELINDA',
#  'WILL',
#  'SPEER',
#  'HALPIN',
#  'RICKIE',
#  'RIVERS',
#  'BURNS',
#  'WHITTEN',
#  'BLANCHARD',
#  'MADIE',
#  'SNODGRASS',
#  'LAURAN',
#  'ALSTON',
#  'SUBLETT',
#  'PAMELA',
#  'CATHCART',
#  'BURTON',
#  'DIMPLE',
#  'MARIEL',
#  'MERTZ',
#  'WILLIAM',
#  'BRAXTON',
#  'GARFIELD',
#  'BUELL',
#  'BILLY',
#  'TERRI',
#  'TIMIKA',
#  'PARRY',
#  'RAMBO',
#  'ANTHONY',
#  'ALVERA',
#  'TERENCE',
#  'OMALLEY',
#  'LUNDQUIST',
#  'ALDA',
#  'XUAN',
#  'LINA',
#  'CONCETTA',
#  'SATTLER',
#  'PAK',
#  'HANNELORE',
#  'COVER',
#  'BOBETTE',
#  'ANABEL',
#  'MCGOUGH',
#  'BORGES',
#  'BALCH',
#  'CLARE',
#  'HELGA',
#  'OLIVEIRA',
#  'DUHON',
#  'AMERSON',
#  'QUARLES',
#  'DOVIE',
#  'DOOLITTLE',
#  'NAIDA',
#  'CARMELA',
#  'ASA',
#  'VEGAS',
#  'ALCANTARA',
#  'MENA',
#  'LANTZ',
#  'JACINDA',
#  'NOELLA',
#  'ANGELL',
#  'PRECIADO',
#  'BUMP',
#  'MARYANN',
#  'ROUNDY',
#  'ROYCE',
#  'ETTA',
#  'BALLEW',
#  'CORDES',
#  'LERA',
#  'BENAVIDEZ',
#  'MCNEELY',
#  'DAINA',
#  'HUDSPETH',
#  'HOLM',
#  'SULLINS',
#  'HYE',
#  'CROCKETT',
#  'ANJANETTE',
#  'TILLEY',
#  'SARVER',
#  'BRUMLEY',
#  'HENDRICKS',
#  'ELLINGTON',
#  'LINEBERRY',
#  'THAO',
#  'VOLPE',
#  'ORTEGO',
#  'LEOMA',
#  'ILLINOIS',
#  'LIM',
#  'IS',
#  'MCFARLIN',
#  'STEEL',
#  'TROMBLEY',
#  'RAINA',
#  'HAWORTH',
#  'HUNG',
#  'HUDGINS',
#  'TERRY',
#  'SOKOL',
#  'PROPST',
#  'MCCLURG',
#  'against',
#  'ANTONIETTA',
#  'WARRINGTON',
#  'POLING',
#  'JAN',
#  'FOGARTY',
#  'BURKHARDT',
#  'GABRIELA',
#  'JALEESA',
#  'SIMONA',
#  'LOUETTA',
#  'JEWELL',
#  'CLAUDIO',
#  'ISIS',
#  'LYNCH',
#  'LEIGHA',
#  'MONTANO',
#  'LIA',
#  'AMELIA',
#  'BUSTOS',
#  'LINDGREN',
#  'GENOVEVA',
#  'DANTZLER',
#  'RIDGE',
#  'ELSIE',
#  'DOMBROWSKI',
#  'MIGDALIA',
#  'DACIA',
#  'HANLEY',
#  'COGGINS',
#  'SOCORRO',
#  'KIRKWOOD',
#  'HOULE',
#  'ELENORE',
#  'SCHUMACHER',
#  'PORFIRIO',
#  'ATHERTON',
#  'SEWARD',
#  'SANDI',
#  'JACKS',
#  'LEANDRA',
#  'GARMAN',
#  'DAGGETT',
#  'OTELIA',
#  'ANDRE',
#  'COLLIER',
#  'MADELENE',
#  'DOLLAR',
#  'GOTT',
#  'MCGEE',
#  'DUBE',
#  'MANSOUR',
#  'JANNET',
#  'GREATHOUSE',
#  'OGRADY',
#  'l',
#  'RANSOM',
#  'NYLA',
#  'MORRISSETTE',
#  'LEAH',
#  'JANEY',
#  'ARNOLD',
#  'MELBA',
#  'NEOMI',
#  'BOLT',
#  'different',
#  'LARRY',
#  'SCOGGINS',
#  'RICKEY',
#  'GAUDET',
#  'SIGNE',
#  'BRUNET',
#  'MYRTLE',
#  'BABCOCK',
#  'LANEY',
#  'MARQUITTA',
#  'WRIGHT',
#  'SIGRID',
#  'REECE',
#  'CICELY',
#  'ROCK',
#  'RICKER',
#  'FIELDING',
#  'RANGE',
#  'SHORES',
#  'SUDIE',
#  'ADELA',
#  'LOVELL',
#  'PAZ',
#  'SORAYA',
#  'BARNEY',
#  'LIANNE',
#  'EASON',
#  'LANGE',
#  'HENRY',
#  'THURBER',
#  'ADAM',
#  'LANG',
#  'STOUT',
#  'MANZANO',
#  'these',
#  "won't",
#  'WHITTINGTON',
#  'MEACHAM',
#  'BRECKENRIDGE',
#  'NICHOLE',
#  'KARL',
#  'BEATON',
#  'BART',
#  'ALLEY',
#  'FELKER',
#  'VITA',
#  'VALRIE',
#  'HUNLEY',
#  'NOONAN',
#  'DUNAGAN',
#  'VANDYKE',
#  'SOARES',
#  'ARDOIN',
#  'BESSIE',
#  'NEW LIRA',
#  'BAINES',
#  'REGO',
#  'BROADNAX',
#  'DANN',
#  'KNOWLES',
#  'HASSELL',
#  'NUNN',
#  'NORFLEET',
#  'HUMBLE',
#  'DICKENSON',
#  'GRANT',
#  'JEANA',
#  'CHURCH',
#  'JANEL',
#  'KAVANAUGH',
#  'STCLAIR',
#  'KRISTINA',
#  'NEVADA',
#  'WILCHER',
#  'AGEE',
#  'HUGHEY',
#  'PAMALA',
#  'SOUTHERLAND',
#  'selves',
#  'GUIDO',
#  'ASHLI',
#  'KATO',
#  'BURRELL',
#  'LOUDERMILK',
#  'LOREN',
#  'TABATHA',
#  'LAMONT',
#  'DECK',
#  'JULIANNE',
#  'LATOYIA',
#  'afterwards',
#  'LATIA',
#  'VOIGT',
#  'MEAGAN',
#  'LUSK',
#  'CYRIL',
#  'BASSETT',
#  'MING',
#  'CIRA',
#  'BUSCH',
#  'everybody',
#  'ROSELINE',
#  'JANNA',
#  'ROBBIN',
#  'KAPLAN',
#  'SUISSE',
#  'BELGIUM',
#  'anyhow',
#  'LAKENDRA',
#  'BERNIE',
#  'useful',
#  'MAR',
#  'OVERSTREET',
#  'CHANTAY',
#  'CADY',
#  'ATKINS',
#  'GRAVES',
#  'PRICE',
#  'FRAN',
#  'why',
#  'MERRIE',
#  'STRAWN',
#  'PITTS',
#  'TREADWAY',
#  'FREDERICKS',
#  'SEPTEMBER',
#  'TAMBRA',
#  'GRIFFIS',
#  'SCRUGGS',
#  'HANA',
#  'MAGDALENA',
#  'RACHAEL',
#  'BUTLER',
#  'STULTZ',
#  'GEMMA',
#  'BREE',
#  'HOY',
#  'SCHULMAN',
#  'ESTRELLA',
#  'VALENTI',
#  'HACKWORTH',
#  'TOMI',
#  'CORNEJO',
#  'LOVE',
#  'KIEFFER',
#  'MESSIER',
#  'KYLE',
#  'WILLS',
#  'LEHMAN',
#  'SHERRILL',
#  'MICHELINE',
#  'STOLTZFUS',
#  'MYER',
#  'MARLEEN',
#  'LOIDA',
#  'CUOMO',
#  'ENEIDA',
#  'BEEMAN',
#  'ARDITH',
#  'DENISE',
#  'HALBERT',
#  'RUTTER',
#  'better',
#  'STHILAIRE',
#  'LYNWOOD',
#  'MERLENE',
#  'KNIGHT',
#  'WHITTLE',
#  'GORE',
#  'BUNTON',
#  'SERENA',
#  'VIRGIL',
#  'CALLOWAY',
#  'CANDY',
#  'DUKES',
#  'TENNEY',
#  'NITA',
#  'THEA',
#  'RUTHE',
#  'JEFFIE',
#  "couldn't",
#  'WATANABE',
#  'GREGOIRE',
#  'INGE',
#  'except',
#  'BRISTOL',
#  'CRYSTLE',
#  'hence',
#  'GALLEGOS',
#  'CAHILL',
#  'FELL',
#  'GERARDO',
#  'LORIA',
#  'PENLAND',
#  'ORALEE',
#  'COLEMAN',
#  'BECKMAN',
#  'SHERYLL',
#  'DOMONIQUE',
#  'SHARRI',
#  'DUNSTON',
#  'DECASTRO',
#  'whether',
#  'GOSS',
#  'COMER',
#  'SOILEAU',
#  'BUGG',
#  'JESUSA',
#  'BRIEN',
#  'MULL',
#  'NICOLASA',
#  'BARTLETT',
#  'NULL',
#  'CAMBELL',
#  'KASSIE',
#  'LIGIA',
#  'ESCAMILLA',
#  'BEY',
#  'HELLEN',
#  'NATASHIA',
#  'VIRGILIO',
#  'SCHAEFER',
#  'DEARING',
#  'EIGHTEEN',
#  'MADALENE',
#  'KWAN',
#  'BYLER',
#  'DOMINIQUE',
#  'JOLLY',
#  'LISABETH',
#  'COON',
#  'ROMANA',
#  'STALEY',
#  'LAVENIA',
#  'WILLETT',
#  'LILLIAM',
#  'hopefully',
#  'SHAQUANA',
#  'MOORER',
#  'MENDEZ',
#  'BRITTON',
#  'RIDEOUT',
#  'CASTANEDA',
#  'KANE',
#  'DUNBAR',
#  'GANN',
#  'WEATHERBY',
#  'WILTON',
#  'FREDDA',
#  'QUIRK',
#  'MCAFEE',
#  'WILDMAN',
#  'KAMILAH',
#  "can't",
#  'BARNHILL',
#  'BREEDEN',
#  'JEFFERS',
#  'KEIM',
#  'OCHS',
#  'DOWNES',
#  'GILLIGAN',
#  'inc',
#  'FELICIA',
#  'SELLERS',
#  'BLANDING',
#  'SPRINGER',
#  'ROCKWELL',
#  'BROYLES',
#  'NISHA',
#  'SAMS',
#  'RICCI',
#  'QTR',
#  'BOISVERT',
#  'CLARK',
#  'RAGSDALE',
#  'shall',
#  'METZGER',
#  'too',
#  'HOLCOMBE',
#  'WELLINGTON',
#  'MCDOWELL',
#  'SCHATZ',
#  'WALLY',
#  'NERY',
#  'GONZALES',
#  'BLACKWELL',
#  'MARGART',
#  'GIROUX',
#  'FELDMAN',
#  'per',
#  'KACI',
#  'greetings',
#  'LAURENT',
#  'CLAUDE',
#  'SAWYERS',
#  'VIERRA',
#  'IOWA',
#  "wouldn't",
#  'MULLENS',
#  'SHERRELL',
#  'JAMAAL',
#  'MAGUIRE',
#  'm',
#  'WICK',
#  'c',
#  'AUGUSTINA',
#  'ADCOCK',
#  'MACIEL',
#  'VADA',
#  'ISENBERG',
#  'following',
#  'OKEEFE',
#  'GILLILAND',
#  'CINTHIA',
#  'SULEMA',
#  'LINH',
#  'WINCHELL',
#  'HOWELL',
#  'TYE',
#  'MELVA',
#  'THI',
#  'SUMIKO',
#  'NIETO',
#  'DEBRAH',
#  'COTTRELL',
#  'KLINGER',
#  'TOBI',
#  'SHAKIA',
#  'SHERLENE',
#  'CORNETT',
#  'KUHLMAN',
#  'HURD',
#  'MCGEHEE',
#  'BERNARDINE',
#  'WILLIAMS',
#  'WOLF',
#  'BOGLE',
#  'PULVER',
#  'GUSMAN',
#  'WINONA',
#  'MARICRUZ',
#  'GRABOWSKI',
#  'COOMBS',
#  'HINKLEY',
#  'OCTAVIO',
#  'RETTA',
#  'we',
#  'OTERO',
#  'HAMLIN',
#  'AYESHA',
#  'BRINKMAN',
#  'KEARNS',
#  'ALTMAN',
#  'BANE',
#  'LIZETH',
#  'BONNELL',
#  'SHERIDAN',
#  'SANDY',
#  'TIARA',
#  'SHERLEY',
#  'KOERNER',
#  'ALVARADO',
#  'CINDY',
#  'DUPUIS',
#  'CHARLINE',
#  'RONI',
#  'other',
#  'so',
#  'THERRIEN',
#  'KIA',
#  'LINDSAY',
#  'FENN',
#  'soon',
#  'ALEXIS',
#  'CAROLINA',
#  'BENNER',
#  'POTEAT',
#  'FOUNTAIN',
#  'KERSHAW',
#  'SMALLEY',
#  'SYLVIE',
#  'SLAY',
#  'LORIANN',
#  'BURDETT',
#  'CONNORS',
#  'GALLAHER',
#  'PHILLIPS',
#  'PINE',
#  'ZARAGOZA',
#  'BERENICE',
#  'SHERWOOD',
#  'RADER',
#  'APPLING',
#  'theres',
#  'HARVEY',
#  'NICHELLE',
#  'HAHN',
#  'PAULITA',
#  'ROSIO',
#  'appear',
#  'XIII',
#  'AVELINA',
#  'GEARHART',
#  'TANDRA',
#  'CARSON',
#  'WAITE',
#  'SHANTE',
#  'EMILE',
#  'SANTOS',
#  'that',
#  'ANTONIA',
#  'MICHAUD',
#  'MCCHESNEY',
#  'OCAMPO',
#  'NICHOLSON',
#  'KRYSTA',
#  'PERRY',
#  'PFEFFER',
#  'MORTIMER',
#  'NINETEEN',
#  'HANS',
#  'MILBURN',
#  "haven't",
#  'CAROLE',
#  'anyone',
#  'KENDA',
#  'ENG',
#  'EAGLE',
#  'MCCRACKEN',
#  'BLOCK',
#  'ROSY',
#  'ROSSMAN',
#  'CHAFFEE',
#  'SHIRLY',
#  'know',
#  'JANIE',
#  'DEVRIES',
#  'SACHS',
#  'NELIA',
#  'CATHERYN',
#  'HERS',
#  'somebody',
#  'IBARRA',
#  'DARLENE',
#  'PENTON',
#  'DEJA',
#  'also',
#  'POLLY',
#  'NOEL',
#  'SHENNA',
#  'OSBORNE',
#  'BOX',
#  'PYLES',
#  'OATES',
#  'MCCLEARY',
#  'BINION',
#  'PATEL',
#  'KAITLIN',
#  'ABRAHAM',
#  'VERNETTA',
#  'HAMILL',
#  'SEARCY',
#  'MISTY',
#  'GASKILL',
#  'JANETH',
#  'WERE',
#  'SAUNDRA',
#  'GREENBERG',
#  'IRVIN',
#  'GUO',
#  'MILDRED',
#  'CHANTE',
#  'PEELE',
#  'BRITTANY',
#  'ASTRID',
#  'JERRICA',
#  'HAYGOOD',
#  'STAMM',
#  'MCAVOY',
#  'CARLTON',
#  'REDD',
#  'PILCHER',
#  'TSAI',
#  'WATTERSON',
#  'OCONNOR',
#  'ZAMORA',
#  'ROSELYN',
#  'BRIGHAM',
#  'COWEN',
#  'BRINKLEY',
#  'EZEQUIEL',
#  'AUREA',
#  'COLELLA',
#  'RENO',
#  'DUNCAN',
#  'GIUSEPPE',
#  'SEA',
#  'DOLL',
#  'DAVEY',
#  'LULU',
#  'CHARLENE',
#  'CATHERIN',
#  'MIRANDA',
#  'SKIDMORE',
#  'CELIA',
#  'KAREY',
#  'PHILIPS',
#  'FAUSTINO',
#  'CARRASQUILLO',
#  'DELHI',
#  'CRISTINA',
#  'BALBOA',
#  'AUDETTE',
#  'SHARAN',
#  'HAGUE',
#  'ODIS',
#  'BLVD',
#  'BRAITHWAITE',
#  'BITTNER',
#  'particularly',
#  'HUDGENS',
#  "isn't",
#  'KESTER',
#  'KYRA',
#  'ROSENBERGER',
#  'HARDIMAN',
#  'SPRINKLE',
#  'BROWER',
#  'SAMPLE',
#  'FLEMMING',
#  'MEMPHIS',
#  'JETER',
#  'JAVIER',
#  'EASTERLING',
#  'GALLANT',
#  'CRISTOBAL',
#  'WHIPPLE',
#  'KARNES',
#  'TATIANA',
#  'VALENCIA',
#  'HARGIS',
#  'MATHIAS',
#  'TRESSA',
#  'ARIARY',
#  'ESPINAL',
#  'JESENIA',
#  'GLASER',
#  'LORIS',
#  'TIMOTHY',
#  'RAMSEY',
#  'LEATHERWOOD',
#  'ALPHA',
#  'where',
#  'GOULD',
#  'LAUNA',
#  'BUT',
#  'STUART',
#  'HARKNESS',
#  'FOURNIER',
#  'LILIANA',
#  'BECKI',
#  'ROLLAND',
#  'SHIELA',
#  'PAPE',
#  'former',
#  'OAKS',
#  'HUBER',
#  'STUBBLEFIELD',
#  'CROZIER',
#  'CORSO',
#  'CARL',
#  'BASKIN',
#  'BONITA',
#  'DOMINQUE',
#  'BROCK',
#  'MIYOKO',
#  'POK',
#  'WHORTON',
#  'PRATHER',
#  'HIPP',
#  'COLLARD',
#  'SHARLEEN',
#  'NONA',
#  'MARQUEZ',
#  'DEANE',
#  'KATERINE',
#  'KEARNEY',
#  'another',
#  'BRANN',
#  'MERIDITH',
#  'FRY',
#  'MAGGIO',
#  'TAMALA',
#  'LUCIER',
#  'COLUCCI',
#  'CARMELITA',
#  'TRUMAN',
#  'MCLEMORE',
#  'CRISTIN',
#  'ORR',
#  'BEVERLEY',
#  'MEEHAN',
#  'KELI',
#  'MONNIE',
#  'BRAZILIAN',
#  'LILLIAN',
#  'KIANA',
#  'SONA',
#  'DINORAH',
#  'MYRLE',
#  'MARYALICE',
#  'SLATON',
#  'BUFFINGTON',
#  'FURTADO',
#  'MIRTA',
#  'AUGUST',
#  'SOWELL',
#  'KATHRIN',
#  'LAVONIA',
#  'GEE',
#  'PASCHALL',
#  'NEWSOME',
#  'JACKELINE',
#  'OLMOS',
#  'FLOY',
#  'ELDA',
#  'became',
#  'ERMINIA',
#  'SISK',
#  'ABREGO',
#  'CIERRA',
#  'LUBA',
#  'JANETTA',
#  'MANLEY',
#  'STITT',
#  'DANI',
#  'NINO',
#  'CORNELL',
#  'BICE',
#  'CRAIN',
#  'MACIE',
#  'LAIRD',
#  'DUGAS',
#  'TIM',
#  'MAE',
#  'BUNNELL',
#  'DEVER',
#  'MEDRANO',
#  'BRONWYN',
#  'WOODMAN',
#  'WEGNER',
#  'TINGLE',
#  'ALFREDO',
#  'HOROWITZ',
#  'TAMRA',
#  'KOPP',
#  'VILLASENOR',
#  'ZOFIA',
#  'GROFF',
#  'DUSTIN',
#  'HAIGHT',
#  'ALPHONSE',
#  'EILEEN',
#  'ROMANO',
#  'CHANTELL',
#  'MOATS',
#  'DANA',
#  'GONZALO',
#  'IZOLA',
#  'JOYA',
#  'MAN',
#  'POMEROY',
#  'VIKKI',
#  'DUGGER',
#  'TILDA',
#  'POLLEY',
#  'SIMMON',
#  'ARIANA',
#  'DRISKELL',
#  'SATTERFIELD',
#  'MEDA',
#  'ABIGAIL',
#  'BEATTY',
#  'BULLOCK',
#  'FENNER',
#  'GAINES',
#  'KAHN',
#  'GARBER',
#  'GILMORE',
#  'SHONTA',
#  'lately',
#  'ISIDRO',
#  'MARKUS',
#  'SOUTHWEST',
#  'LEAKE',
#  'SAO',
#  'MARGUERITE',
#  'CARDEN',
#  'DARLING',
#  'GLORY',
#  'KENIA',
#  'ANGEL',
#  ...}

# %% [markdown]
# **cleaning the articles by removing the stop words**

# %%
def clean_text(article_text, combine):
    words = article_text.split()
    cleaned_words = [word for word in words if word.lower() not in combine]
    cleaned_text = ' '.join(cleaned_words)
    return cleaned_text

def clean_articles(input_root_folder, stopwords_set):
    for folder_name in os.listdir(input_root_folder):
        folder_path = os.path.join(input_root_folder, folder_name)

        if os.path.isdir(folder_path):
            for file_name in os.listdir(folder_path):
                if file_name.endswith('.txt'):
                    file_path = os.path.join(folder_path, file_name)

                    with open(file_path, 'r', encoding='utf-8') as file:
                        article_text = file.read()

                    cleaned_text = clean_text(article_text, stopwords_set)

                    # Save the cleaned text back to the file
                    with open(file_path, 'w', encoding='utf-8') as file:
                        file.write(cleaned_text)

input_root_folder = "D:\internship\output"
clean_articles(input_root_folder, combine)

# %% [markdown]
# *code to check if the articles are cleaned and display the uncleaned articles*

# %%
def clean_text(article_text, combine):
    words = article_text.split() 
    cleaned_words = [word for word in words if word.lower() not in combine]
    cleaned_text = ' '.join(cleaned_words)
    return cleaned_text

def check_cleaned_status(folder_path, stopwords_set):
    for file_name in os.listdir(folder_path):
        if file_name.endswith('.txt'):
            file_path = os.path.join(folder_path, file_name)
            with open(file_path, 'r', encoding='utf-8') as file:
                original_text = file.read()

            cleaned_text = clean_text(original_text, stopwords_set)
            if original_text != cleaned_text:
                print(f"Article in file {file_path} is not cleaned.")

root_folder = "D:\internship\output"

for folder_name in os.listdir(root_folder):
    folder_path = os.path.join(root_folder, folder_name)
    
    if os.path.isdir(folder_path):
        check_cleaned_status(folder_path, combine)

# %% [markdown]
# **creating document for positive words**

# %%
from docx import Document

def read_positive_words_from_docx(docx_path):
    positive_words = set()

    doc = Document(docx_path)
    for paragraph in doc.paragraphs:
        words = paragraph.text.split()
        positive_words.update(words)

    return positive_words

docx_path = 'D:\internship\positive-words.docx'
positive_words_dict = {'positive': read_positive_words_from_docx(docx_path)}

print("Positive Words:")
pos=(positive_words_dict['positive'])
pos
# Out:
# Positive Words:
# {'adoring',
#  'unbiased',
#  'reformed',
#  'gaining',
#  'well-behaved',
#  'impeccable',
#  'idolize',
#  'exultingly',
#  'cheer',
#  'effusive',
#  'prettily',
#  'thoughtfully',
#  'succeeding',
#  'fortunate',
#  'steadiness',
#  'unencumbered',
#  'eased',
#  'appealing',
#  'graciousness',
#  'jaw-droping',
#  'striving',
#  'ideal',
#  'nifty',
#  'solicitously',
#  'gratified',
#  'astounded',
#  'intriguing',
#  'statuesque',
#  'poise',
#  'novelty',
#  'extraordinarily',
#  'gladly',
#  'freshest',
#  'steadfastly',
#  'cheapest',
#  'aspire',
#  'attentive',
#  'convincing',
#  'cozy',
#  'amicable',
#  'elite',
#  'gratefully',
#  'generously',
#  'leads',
#  'examplary',
#  'rockstars',
#  'revolutionary',
#  'refund',
#  'snappy',
#  'recovery',
#  'achievible',
#  'celebrated',
#  'durable',
#  'overtake',
#  'commodious',
#  'dauntless',
#  'readily',
#  'revives',
#  'salutary',
#  'idol',
#  'eloquently',
#  'brilliances',
#  'openness',
#  'fabulous',
#  'intrigue',
#  'gusto',
#  'accurately',
#  'courageousness',
#  'straighten',
#  'acclamation',
#  'favorited',
#  'effusively',
#  'considerate',
#  'sumptuous',
#  'trusting',
#  'invincibility',
#  'fancier',
#  'defender',
#  'cohere',
#  'achievement',
#  'finest',
#  'goodness',
#  'glistening',
#  'traction',
#  'outdo',
#  'exceled',
#  'venerate',
#  'examplar',
#  'supported',
#  'enhance',
#  'fashionable',
#  'holy',
#  'patriotic',
#  'assurances',
#  'feature-rich',
#  'flutter',
#  'homage',
#  'goood',
#  'astonished',
#  'sensations',
#  'extoll',
#  'first-in-class',
#  'promises',
#  'soundness',
#  'extraordinary',
#  'unfettered',
#  'impeccably',
#  'ambitiously',
#  'keenness',
#  'elegantly',
#  'enterprising',
#  'exceed',
#  'cherish',
#  'fervently',
#  'afordable',
#  'lawful',
#  'openly',
#  'exuberantly',
#  'long-lasting',
#  'god-given',
#  'tantalize',
#  'indulgence',
#  'unquestionably',
#  'adventuresome',
#  'earnestly',
#  'merciful',
#  'intuitive',
#  'gallant',
#  'quicker',
#  'cajole',
#  'amenity',
#  'jubiliant',
#  'sweeten',
#  'cleverly',
#  'affably',
#  'stainless',
#  'elatedly',
#  'beutifully',
#  'eagerness',
#  'carefree',
#  'vibrantly',
#  'willing',
#  'humorous',
#  'easygoing',
#  'benefits',
#  'humility',
#  'laudably',
#  'splendid',
#  'majestic',
#  'prolific',
#  'cute',
#  'fortunately',
#  'priceless',
#  'whoa',
#  'outstanding',
#  'sensation',
#  'responsibly',
#  'darling',
#  'groundbreaking',
#  'fascinating',
#  'reassurance',
#  'excellently',
#  'amaze',
#  'favor',
#  'imaginative',
#  'saint',
#  'glow',
#  'peach',
#  'staunch',
#  'cleanly',
#  'congratulatory',
#  'edify',
#  'cheaper',
#  'boundless',
#  'enlightenment',
#  'memorable',
#  'prestige',
#  'motivated',
#  'safely',
#  'chivalrous',
#  'plusses',
#  'gloriously',
#  'humor',
#  'spellbind',
#  'astound',
#  'marveled',
#  'reachable',
#  'trouble-free',
#  'unequivocal',
#  'serenity',
#  'valor',
#  'aspirations',
#  'terrific',
#  'good',
#  'reconciliation',
#  'qualified',
#  'affirm',
#  'well-managed',
#  'efficient',
#  'tranquility',
#  'inspiration',
#  'reverently',
#  'tantalizingly',
#  'benifits',
#  'adventurous',
#  'gems',
#  'mesmerizing',
#  'pleasingly',
#  'rapture',
#  'ecstasies',
#  'heroic',
#  'dashing',
#  'enviable',
#  'integrated',
#  'preferes',
#  'idolized',
#  'gleefully',
#  'likable',
#  'undaunted',
#  'eye-catching',
#  'effusion',
#  'sumptuously',
#  'luxurious',
#  'felicity',
#  'supreme',
#  'adaptive',
#  'cure-all',
#  'solidarity',
#  'raptureously',
#  'unabashedly',
#  'promised',
#  'neatly',
#  'ingenuous',
#  'selective',
#  'abounds',
#  'boom',
#  'fecilitous',
#  'revitalize',
#  'cost-effective',
#  'enthusiast',
#  'elate',
#  'dominate',
#  'exult',
#  'gain',
#  'excitedness',
#  'exquisite',
#  'comely',
#  'foresight',
#  'spiritual',
#  'accommodative',
#  'clearer',
#  'cohesive',
#  'enhanced',
#  'consistent',
#  'dignity',
#  'honesty',
#  'super',
#  'euphorically',
#  'exultant',
#  'feasibly',
#  'flawlessly',
#  'positive',
#  'embolden',
#  'useful',
#  'greatest',
#  'preferably',
#  'amazes',
#  'attractive',
#  'credible',
#  'miraculously',
#  'resilient',
#  'reclaim',
#  'generous',
#  'euphoric',
#  'useable',
#  'beautifullly',
#  'pure',
#  'jubilation',
#  'winning',
#  'patiently',
#  'generosity',
#  'grin',
#  'mercy',
#  'brainy',
#  'romanticize',
#  'envious',
#  'smoothest',
#  'mercifully',
#  'paradise',
#  'thumb-up',
#  'well-run',
#  'dominated',
#  'exceedingly',
#  'soothe',
#  'stabilize',
#  'ideally',
#  'faithfully',
#  'benefit',
#  'advantageous',
#  'enchanting',
#  'inestimable',
#  'amazingly',
#  'entertaining',
#  'swiftness',
#  'unaffected',
#  'glisten',
#  'better',
#  'clever',
#  'exceeding',
#  'prosper',
#  'heaven',
#  'surpass',
#  'detachable',
#  'reaffirm',
#  'inestimably',
#  'savings',
#  'bargain',
#  'exonerate',
#  'illuminati',
#  'yay',
#  'tempting',
#  'resourceful',
#  'passion',
#  'regally',
#  'inventive',
#  'individualized',
#  'preferring',
#  'suave',
#  'marvelous',
#  'poignant',
#  'decisiveness',
#  'excitedly',
#  'revolutionize',
#  'beckon',
#  'best-performing',
#  'sweeping',
#  'richer',
#  'calmness',
#  'faultless',
#  'cooperative',
#  'cleanliness',
#  'heroize',
#  'courteous',
#  'merit',
#  'laudable',
#  'tranquil',
#  'peace',
#  'spectacularly',
#  'solace',
#  'unwavering',
#  'easiest',
#  'decent',
#  'admire',
#  'opulent',
#  'efficacious',
#  'glad',
#  'cornerstone',
#  'heartfelt',
#  'fertile',
#  'prominent',
#  'well-established',
#  'valiantly',
#  'effortless',
#  'spontaneous',
#  'staunchness',
#  'zippy',
#  'rewardingly',
#  'engaging',
#  'securely',
#  'cherished',
#  'surreal',
#  'incredibly',
#  'multi-purpose',
#  'praiseworthy',
#  'improves',
#  'heroine',
#  'rockstar',
#  'fresh',
#  'commitment',
#  'complimentary',
#  'nourishment',
#  'self-sufficient',
#  'monumental',
#  'conciliatory',
#  'earnest',
#  'sufficiently',
#  'proper',
#  'fastest',
#  'overtook',
#  'dumbfounding',
#  'unity',
#  'hug',
#  'overtaken',
#  'triumph',
#  'impartially',
#  'infallible',
#  'picturesque',
#  'passionately',
#  'strongest',
#  'aver',
#  'gorgeous',
#  'reform',
#  'successes',
#  'brisk',
#  'remarkable',
#  'beckons',
#  'free',
#  'topnotch',
#  'amity',
#  'concise',
#  'indebted',
#  'rapt',
#  'low-risk',
#  'personalized',
#  'welcome',
#  'constructive',
#  'empathy',
#  'expansive',
#  'chivalry',
#  'superior',
#  'speedily',
#  'authentic',
#  'enjoying',
#  'elegance',
#  'unrestricted',
#  'stimulative',
#  'pardon',
#  'awestruck',
#  'masterfully',
#  'revolutionizes',
#  'restored',
#  'simplifies',
#  'cherub',
#  'spellbinding',
#  'adulate',
#  'convincingly',
#  'irresistibly',
#  'keen',
#  'happy',
#  'rapport',
#  'time-honored',
#  'coherence',
#  'marvelled',
#  'pamper',
#  'smooth',
#  'gratify',
#  'believeable',
#  'adore',
#  'spellbound',
#  'fabulously',
#  'nourish',
#  'exuberance',
#  'glitter',
#  'convenience',
#  'satisfies',
#  'problem-solver',
#  'hale',
#  'thrillingly',
#  'amusingly',
#  'lifesaver',
#  'rich',
#  'breathtaking',
#  'dedicated',
#  'laud',
#  'accessable',
#  'healthful',
#  'restructuring',
#  'whooa',
#  'handily',
#  'entrancing',
#  'improved',
#  'top-notch',
#  'intimate',
#  'stately',
#  'excites',
#  'skilled',
#  'obsessions',
#  'successfully',
#  'desiring',
#  'brilliantly',
#  'succeeds',
#  'woo',
#  'impressiveness',
#  'dignify',
#  'sweetly',
#  'painless',
#  'energy-saving',
#  'playfully',
#  'expertly',
#  'decency',
#  'large-capacity',
#  'unmatched',
#  'enthuse',
#  'rejuvenated',
#  'fantastic',
#  'polite',
#  'intelligence',
#  'clear',
#  'agreeableness',
#  'advocated',
#  'spacious',
#  'hilarious',
#  'neat',
#  'non-violent',
#  'convience',
#  'daringly',
#  'invaluablely',
#  'entertain',
#  'fluent',
#  'mature',
#  'cure',
#  'sane',
#  'propitiously',
#  'famed',
#  'refinement',
#  'congratulation',
#  'unquestionable',
#  'continuity',
#  'skill',
#  'agreeably',
#  'adroit',
#  'fiery',
#  'fast-paced',
#  'merrily',
#  'jubilate',
#  'treasure',
#  'posh',
#  'adaptable',
#  'risk-free',
#  'shine',
#  'comforting',
#  'youthful',
#  'thankful',
#  'wowing',
#  'amenable',
#  'wisely',
#  'redeeming',
#  'graceful',
#  'beautiful',
#  'finely',
#  'friendliness',
#  'revere',
#  'elated',
#  'blossom',
#  'thrills',
#  'nimble',
#  'diligent',
#  'liberty',
#  'scenic',
#  'vigilance',
#  'entranced',
#  'pre-eminent',
#  'intricate',
#  'effectively',
#  'modest',
#  'fast-growing',
#  'best-selling',
#  'sporty',
#  'delight',
#  'merriment',
#  'won',
#  'substantive',
#  'firmer',
#  'permissible',
#  'awed',
#  'tops',
#  'peacekeepers',
#  'brighter',
#  'majesty',
#  'finer',
#  'recover',
#  'thoughtfulness',
#  'loyal',
#  'sparkling',
#  'cheerful',
#  'sincere',
#  'blithe',
#  'unbound',
#  'celebratory',
#  'outperforms',
#  'legendary',
#  'stupendous',
#  'gracious',
#  'dependably',
#  'astonishment',
#  'deft',
#  'commendable',
#  'interesting',
#  'stable',
#  'judicious',
#  'low-priced',
#  'solicitous',
#  'gainful',
#  'smartly',
#  'top-quality',
#  'bolster',
#  'pain-free',
#  'adequate',
#  'unconditional',
#  'dynamic',
#  'adored',
#  'amazing',
#  'simplified',
#  'unlimited',
#  'sprightly',
#  'impressed',
#  'wholesome',
#  'rational',
#  'festive',
#  'persevere',
#  'better-known',
#  'correct',
#  'outshine',
#  'inspiring',
#  'flexible',
#  'creative',
#  'relaxed',
#  'educated',
#  'well',
#  'blessing',
#  'favorite',
#  'thriving',
#  'prosperous',
#  'elan',
#  'achievable',
#  'phenomenal',
#  'important',
#  'affectation',
#  'bonny',
#  'glamorous',
#  'leverage',
#  'adoringly',
#  'humorously',
#  'luck',
#  'graciously',
#  'pros',
#  'applaud',
#  'obtainable',
#  'wows',
#  'catchy',
#  'daring',
#  'cashback',
#  'adorable',
#  'toll-free',
#  'prompt',
#  'hearten',
#  'engrossing',
#  'agreeable',
#  'astounding',
#  'freed',
#  'ecstasy',
#  'nice',
#  'gracefully',
#  'prodigy',
#  'exuberant',
#  'exciting',
#  'notably',
#  'smiling',
#  'profuse',
#  'charmingly',
#  'adulatory',
#  'rejuvenating',
#  'admiringly',
#  'self-determination',
#  'seamless',
#  'virtuously',
#  'distinguished',
#  'panoramic',
#  'capability',
#  'feisty',
#  'encourage',
#  'heartwarming',
#  'intimacy',
#  'silent',
#  'quieter',
#  'well-intentioned',
#  'relief',
#  'illumine',
#  'reward',
#  'wonderful',
#  'distinction',
#  'enhancement',
#  'warmer',
#  'gaiety',
#  'reputable',
#  'outperform',
#  'resounding',
#  'salute',
#  'energy-efficient',
#  'agility',
#  'accurate',
#  'gooood',
#  'smile',
#  'support',
#  'feasible',
#  'thumbs-up',
#  'revel',
#  'relish',
#  'state-of-the-art',
#  'assuredly',
#  'quiet',
#  'enticed',
#  'honored',
#  'humour',
#  'gentlest',
#  'receptive',
#  'win',
#  'fearless',
#  'upliftment',
#  'captivating',
#  'rapturously',
#  'pleasure',
#  'success',
#  'relent',
#  'loves',
#  'tenderly',
#  'delightfulness',
#  'noiseless',
#  'delicacy',
#  'worthiness',
#  'like',
#  'upgradeable',
#  'fairness',
#  'phenomenally',
#  'rightful',
#  'sweetheart',
#  'enticing',
#  'hardy',
#  'convient',
#  'endorsement',
#  'luxuriously',
#  'inviolable',
#  'self-sufficiency',
#  'pleasurably',
#  'compactly',
#  'levity',
#  'prospros',
#  'reverent',
#  'cool',
#  'compatible',
#  'luckiest',
#  'illustrious',
#  'plush',
#  'orderly',
#  'stunning',
#  'retractable',
#  'warm',
#  'excelent',
#  'abundance',
#  'restructure',
#  'magnificent',
#  'awards',
#  'speedy',
#  'unfazed',
#  'hospitable',
#  'portable',
#  'handsome',
#  'vigilant',
#  'effectiveness',
#  'well-being',
#  'marvels',
#  'stylized',
#  'alluring',
#  'integral',
#  'worth',
#  'tough',
#  'enraptured',
#  'logical',
#  'accomplish',
#  'dumbfounded',
#  'assuring',
#  'undisputable',
#  'meticulously',
#  'marvel',
#  'gladden',
#  'obsession',
#  'cost-saving',
#  'a+',
#  'evaluative',
#  'hallmark',
#  'dazzled',
#  'sophisticated',
#  'swank',
#  'reforms',
#  'manageable',
#  'destiny',
#  'whoooa',
#  'lustrous',
#  'stellarly',
#  'counter-attacks',
#  'patriot',
#  'ease',
#  'enchanted',
#  'soothingly',
#  'protective',
#  'eloquent',
#  'magic',
#  'foolproof',
#  'admirable',
#  'comprehensive',
#  'easing',
#  'reverence',
#  'rapturous',
#  'gallantly',
#  'cashbacks',
#  'ultra-crisp',
#  'ilu',
#  'harmony',
#  'well-rounded',
#  'dummy-proof',
#  'gladness',
#  'balanced',
#  'momentous',
#  'excels',
#  'trendy',
#  'unequivocally',
#  'precious',
#  'affordable',
#  'rightly',
#  'beautify',
#  'fave',
#  'ardor',
#  'dawn',
#  'fortune',
#  'precise',
#  'pleasing',
#  'audible',
#  'enthusiastic',
#  'honor',
#  'promising',
#  'charm',
#  'knowledgeable',
#  'auspicious',
#  'endorsed',
#  'premier',
#  'beauty',
#  'improve',
#  'slammin',
#  'upheld',
#  'gaily',
#  'beckoned',
#  'steadfastness',
#  'appreciates',
#  'self-satisfaction',
#  'usable',
#  'hallowed',
#  'providence',
#  'thrilling',
#  'pleasant',
#  'kindly',
#  'serene',
#  'protect',
#  'sharp',
#  'genius',
#  'better-than-expected',
#  'breakthroughs',
#  'grand',
#  'stupendously',
#  'wellbeing',
#  'enjoyable',
#  'dotingly',
#  'altruistic',
#  'simplify',
#  'patient',
#  'appeal',
#  'hooray',
#  'effortlessly',
#  'prodigious',
#  'abound',
#  'handsomely',
#  'luxury',
#  'suavely',
#  'unrivaled',
#  'beneficially',
#  'entice',
#  'golden',
#  'spectacular',
#  'instructive',
#  'shiny',
#  'truthful',
#  'defeated',
#  'supple',
#  'trivially',
#  'kudos',
#  'aspiration',
#  'enrich',
#  'charismatic',
#  'admirably',
#  'enjoyably',
#  'variety',
#  'undisputably',
#  'privileged',
#  'clear-cut',
#  'exemplary',
#  'galore',
#  'authoritative',
#  'supremacy',
#  'exceeded',
#  'deserving',
#  'everlasting',
#  'lovable',
#  'elevate',
#  'grandeur',
#  'astutely',
#  'respectable',
#  'low-cost',
#  'slick',
#  'resound',
#  'joyfully',
#  'triumphant',
#  'prowess',
#  'luxuriant',
#  'mesmerizes',
#  'well-bred',
#  'ready',
#  'wonderfully',
#  'easy',
#  'nicer',
#  'convenient',
#  'regard',
#  'radiant',
#  'devout',
#  'sincerity',
#  'complemented',
#  'praising',
#  'stunningly',
#  'willingness',
#  'well-informed',
#  'reasonably',
#  'striking',
#  'extol',
#  'reaffirmation',
#  'coherent',
#  'advocate',
#  'simplest',
#  'lean',
#  'rejoicingly',
#  'clears',
#  'plentiful',
#  'gratifies',
#  'profound',
#  'winner',
#  'high-spirited',
#  'bloom',
#  'pretty',
#  'audibly',
#  'enrapture',
#  'fascination',
#  'titillatingly',
#  'talents',
#  'brilliance',
#  'compliment',
#  'streamlined',
#  'defeat',
#  'prominence',
#  'delectable',
#  'neatest',
#  'deservedly',
#  'transparent',
#  'flourish',
#  'successful',
#  'delicate',
#  'loved',
#  'supporting',
#  'sagely',
#  'zenith',
#  'favored',
#  'steadiest',
#  'unassailable',
#  'evocative',
#  'exaltation',
#  'agile',
#  'succeed',
#  'roomier',
#  'adorer',
#  'hallmarks',
#  'brilliant',
#  'courageously',
#  'glimmer',
#  'worked',
#  'agilely',
#  'benefactor',
#  'renown',
#  'efficiently',
#  'optimism',
#  'regal',
#  'lucky',
#  'sharper',
#  'versatility',
#  'assure',
#  'competitive',
#  'rejuvenate',
#  'rightness',
#  'spellbindingly',
#  'swankier',
#  'reliably',
#  'exellent',
#  'wonder',
#  'evenly',
#  'renewed',
#  ...}

# %% [markdown]
# creating document for negeative words

# %%
def read_words_from_docx(docx_path):
    words = set()

    doc = Document(docx_path)
    for paragraph in doc.paragraphs:
        words.update(paragraph.text.split())

    return words

negative_docx_path = 'D:\\internship\\negative-words.docx'

negative_words_dict = {'negative': read_words_from_docx(negative_docx_path)}

print("Negative Words:")
neg=(negative_words_dict['negative'])
neg
# Out:
# Negative Words:
# {'mispronounces',
#  'muscle-flexing',
#  'ironies',
#  'absence',
#  'nervously',
#  'distress',
#  'conspiracy',
#  'less-developed',
#  'taint',
#  'delaying',
#  'unsatisfactory',
#  'confusions',
#  'starve',
#  'hedge',
#  'misguide',
#  'impertinent',
#  'trauma',
#  'paralize',
#  'hesitant',
#  'incomplete',
#  'itch',
#  'overbearing',
#  'unlawfulness',
#  'reprove',
#  'sorrowful',
#  'asinine',
#  'attacks',
#  'annoyed',
#  'measly',
#  'sever',
#  'debase',
#  'calumniously',
#  'self-coup',
#  'disavowal',
#  'inescapable',
#  'pompous',
#  'worrier',
#  'distrust',
#  'pig',
#  'slower',
#  'startling',
#  'stodgy',
#  'letch',
#  'fiend',
#  'onerously',
#  'avalanche',
#  'depravedly',
#  'importunate',
#  'mortified',
#  'rhetoric',
#  'shocked',
#  'audacious',
#  'barbarously',
#  'upsettingly',
#  'mistrust',
#  'discourteous',
#  'screw-up',
#  'anomalous',
#  'insinuate',
#  'audaciously',
#  'bragger',
#  'wripped',
#  'regressive',
#  'accuse',
#  'impractical',
#  'recourses',
#  'dilly-dally',
#  'grating',
#  'discontinued',
#  'discord',
#  'crashing',
#  'frazzled',
#  'improper',
#  'ire',
#  'mistakes',
#  'deadlock',
#  'despicable',
#  'fierce',
#  'impending',
#  'insignificance',
#  'toil',
#  'war-like',
#  'warp',
#  'flout',
#  'distraction',
#  'shipwreck',
#  'downfallen',
#  'sub-par',
#  'averse',
#  'numb',
#  'unfunded',
#  'exasperatingly',
#  'lament',
#  'weep',
#  'victimize',
#  'quack',
#  'melancholy',
#  'quarrels',
#  'distains',
#  'tricked',
#  'orphan',
#  'overthrows',
#  'alarming',
#  'scathingly',
#  'propaganda',
#  'ho-hum',
#  'heavy-handed',
#  'unclean',
#  'hefty',
#  'felon',
#  'boycott',
#  'chilly',
#  'unrelenting',
#  'smother',
#  'protested',
#  'decry',
#  'peril',
#  'tyrannical',
#  'horrendously',
#  'grimace',
#  'aggravating',
#  'disgustful',
#  'irredeemable',
#  'unacceptable',
#  'mawkishness',
#  'embarrassment',
#  'harbors',
#  'rebuke',
#  'accusation',
#  'harasses',
#  'enmity',
#  'inhuman',
#  'drastic',
#  'loathly',
#  'abominate',
#  'insolently',
#  'abnormal',
#  'disappoint',
#  'inconsequential',
#  'lackey',
#  'lackluster',
#  'sedentary',
#  'occluded',
#  'straining',
#  'dissonantly',
#  'jitter',
#  'deploring',
#  'disagreeable',
#  'chatterbox',
#  'estranged',
#  'dissension',
#  'precipitate',
#  'panic',
#  'barren',
#  'complaining',
#  'smash',
#  'dilapidated',
#  'self-destructive',
#  'unviewable',
#  'blister',
#  'run-down',
#  'darken',
#  'fatty',
#  'refusal',
#  'selfinterested',
#  'erase',
#  'dissenter',
#  'grouse',
#  'unconfirmed',
#  'tumbled',
#  'hamper',
#  'repel',
#  'oppositions',
#  'hampered',
#  'scratched',
#  'juddering',
#  'bugs',
#  'inculcate',
#  'insurrection',
#  'loathing',
#  'troubles',
#  'tetchy',
#  'dizzingly',
#  'inefficiency',
#  'inferior',
#  'scrambled',
#  'corrupt',
#  'longingly',
#  'viper',
#  'vulgar',
#  'dissolute',
#  'mistified',
#  'quibbles',
#  'resent',
#  'debts',
#  'clunky',
#  'unacceptablely',
#  'debauchery',
#  'destains',
#  'stiflingly',
#  'dripped',
#  'douchebag',
#  'dishonor',
#  'puzzlement',
#  'unyielding',
#  'saggy',
#  'indiscreet',
#  'damnation',
#  'rollercoaster',
#  'anti-semites',
#  'judder',
#  'bankrupt',
#  'failures',
#  'flare',
#  'pest',
#  'abomination',
#  'nauseate',
#  'impulsive',
#  'unsteady',
#  'vehement',
#  'noisy',
#  'leech',
#  'moronic',
#  'rusts',
#  'unfriendly',
#  'peeve',
#  'skeptical',
#  'downhill',
#  'hothouse',
#  'irredeemably',
#  'unresolved',
#  'dumping',
#  'cheaply',
#  'impudently',
#  'entrapment',
#  'flirt',
#  'wripping',
#  'heckled',
#  'breaks',
#  'guile',
#  'bore',
#  'restriction',
#  'imprudent',
#  'uncompromising',
#  'break-up',
#  'draining',
#  'dreadful',
#  'belittle',
#  'liability',
#  'racy',
#  'beggar',
#  'craftily',
#  'sham',
#  'crappy',
#  'issue',
#  'haughtily',
#  'idiotically',
#  'oblique',
#  'sorry',
#  'facetiously',
#  'cynicism',
#  'conflicting',
#  'inconceivable',
#  'negate',
#  'stew',
#  'fumble',
#  'infested',
#  'snarky',
#  'irritant',
#  'mistake',
#  'subjection',
#  'squash',
#  'diatribe',
#  'futilely',
#  'frigging',
#  'shirk',
#  'nasty',
#  'jagged',
#  'assault',
#  'berate',
#  'prate',
#  'anarchistic',
#  'one-sided',
#  'disastrous',
#  'irrational',
#  'uproarious',
#  'depress',
#  'horrify',
#  'jealously',
#  'zombie',
#  'bungler',
#  'dejected',
#  'servitude',
#  'beset',
#  'outcast',
#  'patronize',
#  'obsessive',
#  'plea',
#  'chastisement',
#  'devoid',
#  'unnaturally',
#  'nebulously',
#  'criticizing',
#  'disquieting',
#  'slow-moving',
#  'boil',
#  'kaput',
#  'irksomely',
#  'subordinate',
#  'demise',
#  'non-confidence',
#  'bumped',
#  'devastation',
#  'laid-off',
#  'scratches',
#  'exasperation',
#  'inadvisably',
#  'faze',
#  'leak',
#  'freezing',
#  'junky',
#  'rocky',
#  'baffling',
#  'embroil',
#  'snobish',
#  'anti-white',
#  'tragically',
#  'disturb',
#  'fleeing',
#  'hurt',
#  'cramped',
#  'disapointed',
#  'insulting',
#  'lie',
#  'stubborn',
#  'conspicuously',
#  'molestation',
#  'declaim',
#  'irreversible',
#  'stupor',
#  'ruthless',
#  'butcher',
#  'gaff',
#  'unsure',
#  'venom',
#  'grind',
#  'exaggeration',
#  'indigent',
#  'lame',
#  'bicker',
#  'disfavor',
#  'dope',
#  'dimmer',
#  'limit',
#  'scum',
#  'snobs',
#  'lethargy',
#  'malodorous',
#  'unimaginably',
#  'unsuspecting',
#  'polluters',
#  'debaser',
#  'fatuous',
#  'ineptitude',
#  'strangely',
#  'unsupportive',
#  'worries',
#  'molest',
#  'trickery',
#  'mundane',
#  'invective',
#  'overshadow',
#  'escapade',
#  'restlessness',
#  'squabbling',
#  'brimstone',
#  'downfall',
#  'reckless',
#  'illogical',
#  'chintzy',
#  'whine',
#  'lengthy',
#  'mediocrity',
#  'retardedness',
#  'dent',
#  'divergent',
#  'misconceptions',
#  'raging',
#  'garish',
#  'caustic',
#  'dumbfound',
#  'decrement',
#  'ugh',
#  'erroneously',
#  'allegations',
#  'awfulness',
#  'confession',
#  'damage',
#  'maddeningly',
#  'disservice',
#  'pretence',
#  'confront',
#  'vibration',
#  'inexpert',
#  'farcically',
#  'overstate',
#  'irritation',
#  'appallingly',
#  'confess',
#  'morons',
#  'sting',
#  'traumatize',
#  'ill-favored',
#  'aspersions',
#  'panders',
#  'indecisive',
#  'declines',
#  'thrash',
#  'feign',
#  'insane',
#  'complaints',
#  'peevish',
#  'diatribes',
#  'sickly',
#  'fascist',
#  'disown',
#  'inflammatory',
#  'mindless',
#  'struggle',
#  'ghosting',
#  'glare',
#  'stall',
#  'sorrowfully',
#  'lurid',
#  'lividly',
#  'misleadingly',
#  'second-tier',
#  'harboring',
#  'hooligan',
#  'qualm',
#  'inattentive',
#  'yawn',
#  'devastates',
#  'threesome',
#  'objections',
#  'puny',
#  'inclement',
#  'distorted',
#  'inconsistent',
#  'remorsefully',
#  'indecision',
#  'slumpping',
#  'insignificantly',
#  'ripped',
#  'fatal',
#  'scaly',
#  'testy',
#  'wasted',
#  'bother',
#  'cracks',
#  'limited',
#  'dangerous',
#  'woefully',
#  'rampage',
#  'accusing',
#  'flares',
#  'warped',
#  'bulkiness',
#  'ineffectual',
#  'messed',
#  'ghastly',
#  'gloomy',
#  'stab',
#  'oversights',
#  'pitiable',
#  'loathe',
#  'inefficacious',
#  'pales',
#  'smuttiest',
#  'untrue',
#  'detestable',
#  'crueler',
#  'frenetic',
#  'ungrateful',
#  'lazy',
#  'prattle',
#  'upsetting',
#  'self-criticism',
#  'mercilessly',
#  'buzzing',
#  'degradation',
#  'myth',
#  'disgustingly',
#  'punk',
#  'insubstantial',
#  'anemic',
#  'vengefully',
#  'gauche',
#  'gawky',
#  'revolt',
#  'gainsay',
#  'deficiencies',
#  'terror',
#  'gaudy',
#  'snags',
#  'last-ditch',
#  'suppress',
#  'depressingly',
#  'upbraid',
#  'infraction',
#  'intimidate',
#  'mortifying',
#  'left-leaning',
#  'timidly',
#  'freakish',
#  'demonic',
#  'hell',
#  'overwhelming',
#  'shady',
#  'hardliner',
#  'absent-minded',
#  'unfortunate',
#  'enraged',
#  'ranted',
#  'imprudence',
#  'impeach',
#  'shemale',
#  'spurn',
#  'cringed',
#  'destroy',
#  'expropriate',
#  'flagging',
#  'surrender',
#  'joke',
#  'unfit',
#  'sanctimonious',
#  'error',
#  'fruitlessly',
#  'inconsiderately',
#  'seethe',
#  'horrified',
#  'drastically',
#  'grudges',
#  'nag',
#  'confusion',
#  'biases',
#  'friction',
#  'implicate',
#  'bias',
#  'mistaken',
#  'riled',
#  'tricky',
#  'bewail',
#  'costly',
#  'enraging',
#  'loveless',
#  'confrontational',
#  'derogatory',
#  'vague',
#  'incapably',
#  'oversize',
#  'pollute',
#  'invalidate',
#  'mar',
#  'traitor',
#  'knife',
#  'tentative',
#  'unsettling',
#  'timidness',
#  'needlessly',
#  'admonishingly',
#  'dead',
#  'gall',
#  'obsess',
#  'pugnaciously',
#  'unjustified',
#  'dissonant',
#  'unequal',
#  'viciously',
#  'swindle',
#  'neurotic',
#  'undermining',
#  'fell',
#  'creepy',
#  'ineffectually',
#  'tarnishes',
#  'tin-y',
#  'debasement',
#  'frighteningly',
#  'hangs',
#  'addict',
#  'fall',
#  'infiltrator',
#  'predicament',
#  'bunk',
#  'sty',
#  'worthlessly',
#  'capricious',
#  'incomparably',
#  'inflame',
#  'devious',
#  'forgetfully',
#  'devilry',
#  'swamped',
#  'abuse',
#  'cliched',
#  'gimmicked',
#  'irretrievable',
#  'disturbed',
#  'cheerless',
#  'combative',
#  'flakieness',
#  'grossly',
#  'crushing',
#  'infidel',
#  'interfere',
#  'freaking',
#  'confounded',
#  'regret',
#  'scold',
#  'floored',
#  'egomania',
#  'farcical',
#  'contrived',
#  'petrified',
#  'feeblely',
#  'killing',
#  'demolish',
#  'layoff',
#  'chunky',
#  'usurp',
#  'partisan',
#  'tank',
#  'tardy',
#  'invidious',
#  'scorn',
#  'self-interest',
#  'troubling',
#  'damned',
#  'fleed',
#  'nervousness',
#  'devastated',
#  'screwed',
#  'terribleness',
#  'impedance',
#  'foulness',
#  'hallucinate',
#  'swollen',
#  'lurch',
#  'unspeakablely',
#  'damaging',
#  'angrily',
#  'despair',
#  'ludicrous',
#  'contempt',
#  'jobless',
#  'squeal',
#  'foully',
#  'partiality',
#  'denounce',
#  'dishonestly',
#  'twists',
#  'misuse',
#  'dragoon',
#  'indignant',
#  'sully',
#  'ironically',
#  'transgression',
#  'denigrate',
#  'dungeons',
#  'uneventful',
#  'long-winded',
#  'adversary',
#  'asininely',
#  'tainted',
#  'hectic',
#  'unattractive',
#  'childish',
#  'heckles',
#  'hellion',
#  'disintegration',
#  'incessant',
#  'killed',
#  'mess',
#  'nefariously',
#  'acridness',
#  'envious',
#  'pathetic',
#  'stupidly',
#  'upset',
#  'arcane',
#  'backward',
#  'broken',
#  'gruff',
#  'inconsolable',
#  'debility',
#  'detests',
#  'desertion',
#  'deviousness',
#  'unhappily',
#  'bothered',
#  'bullyingly',
#  'itchy',
#  'marginal',
#  'martyrdom-seeking',
#  'infirm',
#  'sluts',
#  'squirm',
#  'faulty',
#  'misgiving',
#  'caricature',
#  'unusual',
#  'tingled',
#  'false',
#  'disrespecting',
#  'blistering',
#  'dick',
#  'mourn',
#  'unsavory',
#  'superficially',
#  'atrocious',
#  'nebulous',
#  'creaking',
#  'taunting',
#  'bleeds',
#  'disrespectful',
#  'fractiously',
#  'miff',
#  'blindside',
#  'conspire',
#  'latency',
#  'anomaly',
#  'dismally',
#  'forlornly',
#  'zealous',
#  'blandish',
#  'eschew',
#  'exclusion',
#  'leery',
#  'merciless',
#  'nonresponsive',
#  'obstructs',
#  'adulteration',
#  'begging',
#  'cumbersome',
#  'sunk',
#  'unjustifiably',
#  'overthrow',
#  'radical',
#  'deplorably',
#  'authoritarian',
#  'carelessness',
#  'effigy',
#  'cripples',
#  'regress',
#  'gabble',
#  'expropriation',
#  'danger',
#  'decadent',
#  'dizzy',
#  'gawk',
#  'dissapointed',
#  'passe',
#  'filthy',
#  'inaction',
#  'inequalities',
#  'incompetently',
#  'instability',
#  'tortuous',
#  'choke',
#  'nepotism',
#  'snarl',
#  'prejudice',
#  'acrimony',
#  'exhaustion',
#  'forgetful',
#  'bruising',
#  'teasingly',
#  'racism',
#  'disappointments',
#  'inadequately',
#  'wrath',
#  'congested',
#  'helpless',
#  'rejecting',
#  'defamations',
#  'hated',
#  'impolite',
#  'ultimatums',
#  'macabre',
#  'outbreak',
#  'demeaning',
#  'frustratingly',
#  'humming',
#  'lonely',
#  'mystery',
#  'shiver',
#  'slaughter',
#  'stringent',
#  'indifference',
#  'gruesome',
#  'die',
#  'snob',
#  'frictions',
#  'hostage',
#  'spade',
#  'subvert',
#  'leaky',
#  'neglected',
#  'ridicule',
#  'sugar-coated',
#  'preposterously',
#  'unappealing',
#  'awkwardness',
#  'bitchy',
#  'ignorance',
#  'stumped',
#  'dogmatic',
#  'whiny',
#  'disloyal',
#  'dupe',
#  'incoherently',
#  'irresolvable',
#  'hegemonistic',
#  'disgusted',
#  'famished',
#  'limitations',
#  'polarisation',
#  'quarrelsome',
#  'antagonistic',
#  'gripe',
#  'injure',
#  'foul',
#  'spank',
#  'unwarranted',
#  'aggravate',
#  'harridan',
#  'derisively',
#  'hastily',
#  'inevitably',
#  'hassles',
#  'criticism',
#  'dissatisfying',
#  'displeasure',
#  'fool',
#  'jealous',
#  'elimination',
#  'bellicose',
#  'excuse',
#  'discouragingly',
#  'infamy',
#  'risk',
#  'torturously',
#  'bored',
#  'disallow',
#  'jaundiced',
#  'condemnation',
#  'forged',
#  'capsize',
#  'spoonfed',
#  'doubtfully',
#  'lecher',
#  'restrict',
#  'stymied',
#  'snobbish',
#  'terrorize',
#  'dictator',
#  'disruptive',
#  'treasonous',
#  'immaterial',
#  'distrusting',
#  'mists',
#  'perplex',
#  'recklessly',
#  'wimpy',
#  'suffocate',
#  'undecided',
#  'fanatically',
#  'retarded',
#  'rival',
#  'reactionary',
#  'mortification',
#  'incongruously',
#  'malign',
#  'rancor',
#  'mindlessly',
#  'perplexing',
#  'glitch',
#  'losing',
#  'indecorum',
#  'scoff',
#  'intermittent',
#  'rremediable',
#  'bruises',
#  'breakups',
#  'destitution',
#  'disgustfully',
#  'second-class',
#  'undone',
#  'wedge',
#  'twist',
#  'ill-advised',
#  'detesting',
#  'untested',
#  'overdone',
#  'repugnant',
#  'worryingly',
#  'blurring',
#  'abysmal',
#  'emphatically',
#  'fuck',
#  'evasion',
#  'emptiness',
#  'kills',
#  'spite',
#  'overstatement',
#  'aghast',
#  'assassin',
#  'anger',
#  'bristle',
#  'halfheartedly',
#  'rascal',
#  'horrible',
#  'contradiction',
#  'matte',
#  'audiciously',
#  'fallen',
#  'plotters',
#  'strain',
#  'barbarian',
#  'disobedience',
#  'disagree',
#  'upsets',
#  'clouding',
#  'recant',
#  'protest',
#  'belligerence',
#  'impatiently',
#  'hissed',
#  'phobic',
#  'sermonize',
#  'drop-outs',
#  'imbroglio',
#  'dictatorial',
#  'demonize',
#  'tentatively',
#  'pertinaciously',
#  'refuted',
#  'dismay',
#  'desolation',
#  'hate',
#  'sufferers',
#  'erratic',
#  'irks',
#  'ruts',
#  'slanders',
#  'jeopardy',
#  'admonition',
#  'stutter',
#  'extremism',
#  'clique',
#  'lurk',
#  'opponent',
#  'sneaky',
#  'dissatisfaction',
#  'pittance',
#  'frustrating',
#  'squander',
#  'apathetically',
#  'deceit',
#  'loner',
#  'lech',
#  'woebegone',
#  'virulently',
#  'confrontation',
#  'noises',
#  'shrew',
#  'loneliness',
#  'renounce',
#  'fears',
#  'puppets',
#  'unseemly',
#  'condemnable',
#  'mystify',
#  'bastard',
#  'disgracefully',
#  'unbearable',
#  'dirty',
#  'petty',
#  'gravely',
#  'dislike',
#  'acridly',
#  'pigs',
#  'bravado',
#  'greedy',
#  'downbeat',
#  'inexorable',
#  'cataclysmic',
#  'commotion',
#  'hatred',
#  ...}

# %% [markdown]
# **removing words from positive and negative words which is present in the stop words**

# %%
pos -= combine
neg -= combine

print("Updated Positive Words:")
print(pos)

print("\nUpdated Negative Words:")
print(neg)
# Out:
# Updated Positive Words:
# {'adoring', 'unbiased', 'reformed', 'gaining', 'well-behaved', 'impeccable', 'idolize', 'exultingly', 'cheer', 'effusive', 'prettily', 'thoughtfully', 'succeeding', 'fortunate', 'steadiness', 'unencumbered', 'eased', 'appealing', 'graciousness', 'jaw-droping', 'striving', 'ideal', 'nifty', 'solicitously', 'gratified', 'astounded', 'intriguing', 'statuesque', 'poise', 'novelty', 'extraordinarily', 'gladly', 'freshest', 'steadfastly', 'cheapest', 'aspire', 'attentive', 'convincing', 'cozy', 'amicable', 'elite', 'gratefully', 'generously', 'leads', 'examplary', 'rockstars', 'revolutionary', 'refund', 'snappy', 'recovery', 'achievible', 'celebrated', 'durable', 'overtake', 'commodious', 'dauntless', 'readily', 'revives', 'salutary', 'idol', 'eloquently', 'brilliances', 'openness', 'fabulous', 'intrigue', 'gusto', 'accurately', 'courageousness', 'straighten', 'acclamation', 'favorited', 'effusively', 'considerate', 'sumptuous', 'trusting', 'invincibility', 'fancier', 'defender', 'cohere', 'achievement', 'finest', 'goodness', 'glistening', 'traction', 'outdo', 'exceled', 'venerate', 'examplar', 'supported', 'enhance', 'fashionable', 'holy', 'patriotic', 'assurances', 'feature-rich', 'flutter', 'homage', 'goood', 'astonished', 'sensations', 'extoll', 'first-in-class', 'promises', 'soundness', 'extraordinary', 'unfettered', 'impeccably', 'ambitiously', 'keenness', 'elegantly', 'enterprising', 'exceed', 'cherish', 'fervently', 'afordable', 'lawful', 'openly', 'exuberantly', 'long-lasting', 'god-given', 'tantalize', 'indulgence', 'unquestionably', 'adventuresome', 'earnestly', 'merciful', 'intuitive', 'gallant', 'quicker', 'cajole', 'amenity', 'jubiliant', 'sweeten', 'cleverly', 'affably', 'stainless', 'elatedly', 'beutifully', 'eagerness', 'carefree', 'vibrantly', 'humorous', 'easygoing', 'benefits', 'humility', 'laudably', 'splendid', 'majestic', 'prolific', 'cute', 'fortunately', 'priceless', 'whoa', 'outstanding', 'sensation', 'responsibly', 'darling', 'groundbreaking', 'fascinating', 'reassurance', 'excellently', 'amaze', 'favor', 'imaginative', 'saint', 'glow', 'peach', 'staunch', 'cleanly', 'congratulatory', 'edify', 'cheaper', 'boundless', 'enlightenment', 'memorable', 'prestige', 'motivated', 'safely', 'chivalrous', 'plusses', 'gloriously', 'humor', 'spellbind', 'astound', 'marveled', 'reachable', 'trouble-free', 'unequivocal', 'serenity', 'valor', 'aspirations', 'terrific', 'good', 'reconciliation', 'qualified', 'affirm', 'well-managed', 'efficient', 'tranquility', 'inspiration', 'reverently', 'tantalizingly', 'benifits', 'adventurous', 'gems', 'mesmerizing', 'pleasingly', 'rapture', 'ecstasies', 'heroic', 'dashing', 'enviable', 'integrated', 'preferes', 'idolized', 'gleefully', 'likable', 'undaunted', 'eye-catching', 'effusion', 'sumptuously', 'luxurious', 'felicity', 'supreme', 'adaptive', 'cure-all', 'solidarity', 'raptureously', 'unabashedly', 'promised', 'neatly', 'ingenuous', 'selective', 'abounds', 'boom', 'fecilitous', 'revitalize', 'cost-effective', 'enthusiast', 'elate', 'dominate', 'exult', 'gain', 'excitedness', 'exquisite', 'comely', 'foresight', 'spiritual', 'accommodative', 'clearer', 'cohesive', 'enhanced', 'consistent', 'dignity', 'honesty', 'super', 'euphorically', 'exultant', 'feasibly', 'flawlessly', 'positive', 'embolden', 'greatest', 'preferably', 'amazes', 'attractive', 'credible', 'miraculously', 'resilient', 'reclaim', 'generous', 'euphoric', 'useable', 'beautifullly', 'pure', 'jubilation', 'winning', 'patiently', 'generosity', 'grin', 'mercy', 'brainy', 'romanticize', 'envious', 'smoothest', 'mercifully', 'paradise', 'thumb-up', 'well-run', 'dominated', 'exceedingly', 'soothe', 'stabilize', 'ideally', 'faithfully', 'benefit', 'advantageous', 'enchanting', 'inestimable', 'amazingly', 'entertaining', 'swiftness', 'unaffected', 'glisten', 'clever', 'exceeding', 'prosper', 'heaven', 'surpass', 'detachable', 'reaffirm', 'inestimably', 'savings', 'bargain', 'exonerate', 'illuminati', 'yay', 'tempting', 'res ...
#
# Updated Negative Words:
# {'mispronounces', 'muscle-flexing', 'ironies', 'absence', 'nervously', 'distress', 'conspiracy', 'less-developed', 'taint', 'delaying', 'unsatisfactory', 'confusions', 'starve', 'hedge', 'misguide', 'impertinent', 'trauma', 'paralize', 'hesitant', 'incomplete', 'itch', 'overbearing', 'unlawfulness', 'reprove', 'sorrowful', 'asinine', 'attacks', 'annoyed', 'measly', 'sever', 'debase', 'calumniously', 'self-coup', 'disavowal', 'inescapable', 'pompous', 'worrier', 'distrust', 'pig', 'slower', 'startling', 'stodgy', 'letch', 'fiend', 'onerously', 'avalanche', 'depravedly', 'importunate', 'mortified', 'rhetoric', 'shocked', 'audacious', 'barbarously', 'upsettingly', 'mistrust', 'discourteous', 'screw-up', 'anomalous', 'insinuate', 'audaciously', 'bragger', 'wripped', 'regressive', 'accuse', 'impractical', 'recourses', 'dilly-dally', 'grating', 'discontinued', 'discord', 'crashing', 'frazzled', 'improper', 'ire', 'mistakes', 'deadlock', 'despicable', 'fierce', 'impending', 'insignificance', 'toil', 'war-like', 'warp', 'flout', 'distraction', 'shipwreck', 'downfallen', 'sub-par', 'averse', 'numb', 'unfunded', 'exasperatingly', 'lament', 'weep', 'victimize', 'quack', 'melancholy', 'quarrels', 'distains', 'tricked', 'orphan', 'overthrows', 'alarming', 'scathingly', 'propaganda', 'ho-hum', 'heavy-handed', 'unclean', 'hefty', 'felon', 'boycott', 'chilly', 'unrelenting', 'smother', 'protested', 'decry', 'peril', 'tyrannical', 'horrendously', 'grimace', 'aggravating', 'disgustful', 'irredeemable', 'unacceptable', 'mawkishness', 'embarrassment', 'harbors', 'rebuke', 'accusation', 'harasses', 'enmity', 'inhuman', 'drastic', 'loathly', 'abominate', 'insolently', 'abnormal', 'disappoint', 'inconsequential', 'lackey', 'lackluster', 'sedentary', 'occluded', 'straining', 'dissonantly', 'jitter', 'deploring', 'disagreeable', 'chatterbox', 'estranged', 'dissension', 'precipitate', 'panic', 'barren', 'complaining', 'smash', 'dilapidated', 'self-destructive', 'unviewable', 'blister', 'run-down', 'darken', 'fatty', 'refusal', 'selfinterested', 'erase', 'dissenter', 'grouse', 'unconfirmed', 'tumbled', 'hamper', 'repel', 'oppositions', 'hampered', 'scratched', 'juddering', 'bugs', 'inculcate', 'insurrection', 'loathing', 'troubles', 'tetchy', 'dizzingly', 'inefficiency', 'inferior', 'scrambled', 'corrupt', 'longingly', 'viper', 'vulgar', 'dissolute', 'mistified', 'quibbles', 'resent', 'debts', 'clunky', 'unacceptablely', 'debauchery', 'destains', 'stiflingly', 'dripped', 'douchebag', 'dishonor', 'puzzlement', 'unyielding', 'saggy', 'indiscreet', 'damnation', 'rollercoaster', 'anti-semites', 'judder', 'bankrupt', 'failures', 'flare', 'pest', 'abomination', 'nauseate', 'impulsive', 'unsteady', 'vehement', 'noisy', 'leech', 'moronic', 'rusts', 'unfriendly', 'peeve', 'skeptical', 'downhill', 'hothouse', 'irredeemably', 'unresolved', 'dumping', 'cheaply', 'impudently', 'entrapment', 'flirt', 'wripping', 'heckled', 'breaks', 'guile', 'bore', 'restriction', 'imprudent', 'uncompromising', 'break-up', 'draining', 'dreadful', 'belittle', 'liability', 'racy', 'beggar', 'craftily', 'sham', 'crappy', 'issue', 'haughtily', 'idiotically', 'oblique', 'facetiously', 'cynicism', 'conflicting', 'inconceivable', 'negate', 'stew', 'fumble', 'infested', 'snarky', 'irritant', 'mistake', 'subjection', 'squash', 'diatribe', 'futilely', 'frigging', 'shirk', 'nasty', 'jagged', 'assault', 'berate', 'prate', 'anarchistic', 'one-sided', 'disastrous', 'irrational', 'uproarious', 'depress', 'horrify', 'jealously', 'zombie', 'bungler', 'dejected', 'servitude', 'beset', 'outcast', 'patronize', 'obsessive', 'plea', 'chastisement', 'devoid', 'unnaturally', 'nebulously', 'criticizing', 'disquieting', 'slow-moving', 'boil', 'kaput', 'irksomely', 'subordinate', 'demise', 'non-confidence', 'bumped', 'devastation', 'laid-off', 'scratches', 'exasperation', 'inadvisably', 'faze', 'leak', 'freezing', 'junky', 'rocky', 'baffling', 'embroil', 'snobish', 'anti-white', 'tragically', 'disturb', 'fleei ...

# %% [markdown]
# **defining separate functions to calculate positive score, negative score, polarity score,subjective score, average sentence length, percentage of complex words, Fog Index, average number of words per sentence, syllables per word, personal pronouns count, average word length,  total words**

# %%
import re
import os
import pandas as pd
import math

#positive score
def calculate_positive_score(text, pos):
    tokens = text.lower().split()
    positive_score = sum(1 for token in tokens if token in pos)
    return positive_score

#negative score
def calculate_negative_score(text, neg):
    tokens = text.lower().split()
    negative_score = sum(1 for token in tokens if token in neg)
    return negative_score
#polarity score
def calculate_polarity_score(positive_score, negative_score):
    return (positive_score - negative_score) / ((positive_score + negative_score) + 0.000001)

#subjective score
def calculate_subjectivity_score(positive_score, negative_score, total_words):
    return (positive_score + negative_score) / (total_words + 0.000001)

def calculate_readability_scores(text):
    sentences = re.split(r'\.', text)

    #average sentence length
    total_words = len(re.findall(r'\b\w+\b', text))
    average_sentence_length = total_words / len(sentences)
    
    #percentage of complex words
    complex_words = [word for word in re.findall(r'\b\w+\b', text) if len(word) > 6] 
    percentage_complex_words = len(complex_words) / total_words
    
    #Fog Index
    fog_index = 0.4 * (average_sentence_length + percentage_complex_words)
    
    return average_sentence_length, percentage_complex_words, fog_index

def calculate_additional_scores(text):
    #average number of words per sentence
    total_sentences = len(re.split(r'\.', text))
    total_words = len(re.findall(r'\b\w+\b', text))
    average_words_per_sentence = (total_words / total_sentences) if total_sentences > 0 else 0
    
    #syllables per word
    syllables_per_word = sum(len(re.findall(r'[aeiouy]+', word)) for word in re.findall(r'\b\w+\b', text))
    
    #personal pronouns count
    personal_pronouns = re.findall(r'\b(?:i|we|my|ours|us)\b', text, flags=re.IGNORECASE)
    personal_pronouns_count = len(personal_pronouns)
    
    #average word length
    total_characters = sum(len(word) for word in re.findall(r'\b\w+\b', text))
    average_word_length = total_characters / total_words if total_words > 0 else 0  # Avoid division by zero

    complex_words_count = len([word for word in re.findall(r'\b\w+\b', text) if len(re.findall(r'[aeiouy]+', word)) > 2])
    

    return average_words_per_sentence, syllables_per_word, personal_pronouns_count, average_word_length,total_words,complex_words_count

#root folder
root_folder = "D:/internship/output"

# Read the document with URL ID, URL, Positive Score, and Negative Score columns into a pandas DataFrame
document_path = "D:/internship/Output Data Structure.xlsx"
df = pd.read_excel(document_path)

# Initializing lists to store values
url_ids = []
positive_scores = []
negative_scores = []
polarity_scores = []
subjectivity_scores = []
url_ids_readability = []
average_sentence_lengths = []
percentage_complex_words_list = []
fog_indices = []
url_ids_additional = []
average_words_per_sentence_list = []
syllables_per_word_list = []
personal_pronouns_count_list = []
average_word_length_list = []
complex_words_count_list = []
word_count_list = []

# Iterate through each subfolder and calculate scores for each article
for folder_name in os.listdir(root_folder):
    folder_path = os.path.join(root_folder, folder_name)
    
    #extract numeric part from the folder name
    url_id_match = re.search(r'\d+', folder_name)
    if url_id_match:
        url_id = folder_name
    else:
        continue
    
    for article_name in os.listdir(folder_path):
        article_path = os.path.join(folder_path, article_name)
        
        with open(article_path, 'r', encoding='utf-8') as file:
            article_text = file.read()
            positive_score = calculate_positive_score(article_text, pos)
            negative_score = calculate_negative_score(article_text, neg)
            polarity_score = calculate_polarity_score(positive_score, negative_score)
            total_words = len(re.findall(r'\b\w+\b', article_text))
            subjectivity_score = calculate_subjectivity_score(positive_score, negative_score, total_words)
            average_sentence_length, percentage_complex_words, fog_index = calculate_readability_scores(article_text)
            average_words_per_sentence, syllables_per_word, personal_pronouns_count, average_word_length,word_count,complex_words_count = calculate_additional_scores(article_text)
            
            
            # Check for missing scores
            if pd.notna(positive_score) and pd.notna(negative_score):
                # Appending values to the lists
                url_ids.append(url_id)
                positive_scores.append(positive_score)
                negative_scores.append(negative_score)
                polarity_scores.append(polarity_score)
                subjectivity_scores.append(subjectivity_score)
                url_ids_readability.append(url_id)
                average_sentence_lengths.append(average_sentence_length)
                percentage_complex_words_list.append(percentage_complex_words)
                fog_indices.append(fog_index)
                url_ids_additional.append(url_id)
                average_words_per_sentence_list.append(average_words_per_sentence)
                syllables_per_word_list.append(syllables_per_word)
                personal_pronouns_count_list.append(personal_pronouns_count)
                average_word_length_list.append(average_word_length)
                complex_words_count_list.append(complex_words_count)
                word_count_list.append(word_count)


#new DataFrame for all scores from the lists
df_scores = pd.DataFrame({
    'URL_ID': url_ids,
    'POSITIVE SCORE': positive_scores,
    'NEGATIVE SCORE': negative_scores,
    'POLARITY SCORE': polarity_scores,
    'SUBJECTIVITY SCORE': subjectivity_scores,
    'URL_ID': url_ids_readability,
    'AVERAGE SENTENCE LENGTH': average_sentence_lengths,
    'PERCENTAGE OF COMPLEX WORDS': percentage_complex_words_list,
    'FOG INDEX': fog_indices,
    'URL_ID': url_ids_additional,
    'AVERAGE WORDS PER SENTENCE': average_words_per_sentence_list,
    'SYLLABLES PER WORD': syllables_per_word_list,
    'PERSONAL PRONOUNS COUNT': personal_pronouns_count_list,
    'AVERAGE WORD LENGTH': average_word_length_list,
    'COMPLEX WORD COUNT': complex_words_count_list,
    'WORD COUNT': word_count_list
})

print(df_scores)
# Out:
#              URL_ID  POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  \
# 0   blackassign0001              10               4        0.428571
# 1   blackassign0002              51              26        0.324675
# 2   blackassign0003              38              23        0.245902
# 3   blackassign0004              34              65       -0.313131
# 4   blackassign0005              21              10        0.354839
# ..              ...             ...             ...             ...
# 95  blackassign0096              30              53       -0.277108
# 96  blackassign0097              25              35       -0.166667
# 97  blackassign0098               4               3        0.142857
# 98  blackassign0099              16               5        0.523809
# 99  blackassign0100              30              46       -0.210526
#
#     SUBJECTIVITY SCORE  AVERAGE SENTENCE LENGTH  PERCENTAGE OF COMPLEX WORDS  \
# 0             0.044728                10.433333                     0.373802
# 1             0.081741                11.214286                     0.515924
# 2             0.077118                12.967213                     0.619469
# 3             0.129243                13.678571                     0.629243
# 4             0.058271                12.090909                     0.522556
# ..                 ...                      ...                          ...
# 95            0.110226                13.446429                     0.508632
# 96            0.098039                14.232558                     0.419935
# 97            0.030172                25.777778                     0.387931
# 98            0.050119                12.323529                     0.400955
# 99            0.119874                17.135135                     0.488959
#
#     FOG INDEX  AVERAGE WORDS PER SENTENCE  SYLLABLES PER WORD  \
# 0    4.322854                   10.433333                 657
# 1    4.692084                   11.214286                2263
# 2    5.434673                   12.967213                2128
# 3    5.723126                   13.678571                1998
# 4    5.045386                   12.090909                1175
# ..        ...                         ...                 ...
# 95   5.582024                   13.446429                1739
# 96   5.860997                   14.232558                1286
# 97  10.466284                   25.777778                 480
# 98   5.089794                   12.323529                 828
# 99   7.049638                   17.135135                1401
#
#     PERSONAL PRONOUNS COUNT  AVERAGE WORD LENGTH  COMPLEX WORD COUNT  \
# 0                         2             6.290735                 100
# 1                         3             7.025478                 401
# 2                         1             7.671302                 413
# 3                         1             7.597911                 384
# 4                         1             6.898496                 208
# ..                      ...                  ...                 ...
# 95                        3             6.810093                 311
# 96                        3             6.349673                 206
# 97                        1             6.443966                  77
# 98                        1             6.202864                 132
# 99                        3             6.675079                 243
#
#     WORD COUNT
# 0          313
# 1          942
# 2          791
# 3          766
# 4          532
# ..         ...
# 95         753
# 96         612
# 97         232
# 98         419
# 99         634
#
# [100 rows x 14 columns]

# %%
df= pd.read_excel("D:\internship\Output Data Structure.xlsx")
df
# Out:
#              URL_ID                                                URL  \
# 0   blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1   blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2   blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3   blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4   blackassign0005  https://insights.blackcoffer.com/ott-platform-...
# ..              ...                                                ...
# 95  blackassign0096  https://insights.blackcoffer.com/what-is-the-r...
# 96  blackassign0097  https://insights.blackcoffer.com/impact-of-cov...
# 97  blackassign0098  https://insights.blackcoffer.com/contribution-...
# 98  blackassign0099  https://insights.blackcoffer.com/how-covid-19-...
# 99  blackassign0100  https://insights.blackcoffer.com/how-will-covi...
#
#     POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# 0              NaN             NaN             NaN                 NaN
# 1              NaN             NaN             NaN                 NaN
# 2              NaN             NaN             NaN                 NaN
# 3              NaN             NaN             NaN                 NaN
# 4              NaN             NaN             NaN                 NaN
# ..             ...             ...             ...                 ...
# 95             NaN             NaN             NaN                 NaN
# 96             NaN             NaN             NaN                 NaN
# 97             NaN             NaN             NaN                 NaN
# 98             NaN             NaN             NaN                 NaN
# 99             NaN             NaN             NaN                 NaN
#
#     AVG SENTENCE LENGTH  PERCENTAGE OF COMPLEX WORDS  FOG INDEX  \
# 0                   NaN                          NaN        NaN
# 1                   NaN                          NaN        NaN
# 2                   NaN                          NaN        NaN
# 3                   NaN                          NaN        NaN
# 4                   NaN                          NaN        NaN
# ..                  ...                          ...        ...
# 95                  NaN                          NaN        NaN
# 96                  NaN                          NaN        NaN
# 97                  NaN                          NaN        NaN
# 98                  NaN                          NaN        NaN
# 99                  NaN                          NaN        NaN
#
#     AVG NUMBER OF WORDS PER SENTENCE  COMPLEX WORD COUNT  WORD COUNT  \
# 0                                NaN                 NaN         NaN
# 1                                NaN                 NaN         NaN
# 2                                NaN                 NaN         NaN
# 3                                NaN                 NaN         NaN
# 4                                NaN                 NaN         NaN
# ..                               ...                 ...         ...
# 95                               NaN                 NaN         NaN
# 96                               NaN                 NaN         NaN
# 97                               NaN                 NaN         NaN
# 98                               NaN                 NaN         NaN
# 99                               NaN                 NaN         NaN
#
#     SYLLABLE PER WORD  PERSONAL PRONOUNS  AVG WORD LENGTH
# 0                 NaN                NaN              NaN
# 1                 NaN                NaN              NaN
# 2                 NaN                NaN              NaN
# 3                 NaN                NaN              NaN
# 4                 NaN                NaN              NaN
# ..                ...                ...              ...
# 95                NaN                NaN              NaN
# 96                NaN                NaN              NaN
# 97                NaN                NaN              NaN
# 98                NaN                NaN              NaN
# 99                NaN                NaN              NaN
#
# [100 rows x 15 columns]

# %%
df_scores.columns
# Out:
# Index(['URL_ID', 'POSITIVE SCORE', 'NEGATIVE SCORE', 'POLARITY SCORE',
#        'SUBJECTIVITY SCORE', 'AVERAGE SENTENCE LENGTH',
#        'PERCENTAGE OF COMPLEX WORDS', 'FOG INDEX',
#        'AVERAGE WORDS PER SENTENCE', 'SYLLABLES PER WORD',
#        'PERSONAL PRONOUNS COUNT', 'AVERAGE WORD LENGTH', 'COMPLEX WORD COUNT',
#        'WORD COUNT'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['URL_ID', 'URL', 'POSITIVE SCORE', 'NEGATIVE SCORE', 'POLARITY SCORE',
#        'SUBJECTIVITY SCORE', 'AVG SENTENCE LENGTH',
#        'PERCENTAGE OF COMPLEX WORDS', 'FOG INDEX',
#        'AVG NUMBER OF WORDS PER SENTENCE', 'COMPLEX WORD COUNT', 'WORD COUNT',
#        'SYLLABLE PER WORD', 'PERSONAL PRONOUNS', 'AVG WORD LENGTH'],
#       dtype='object')

# %%
col = {
    'AVERAGE WORDS PER SENTENCE': 'AVG NUMBER OF WORDS PER SENTENCE',
    'SYLLABLES PER WORD': 'SYLLABLE PER WORD',
    'PERSONAL PRONOUNS COUNT': 'PERSONAL PRONOUNS',
    'AVERAGE WORD LENGTH': 'AVG WORD LENGTH',
    'AVERAGE SENTENCE LENGTH':'AVG SENTENCE LENGTH'
}

df_scores.rename(columns=col, inplace=True)

# %%
columns_to_drop = ['POSITIVE SCORE', 'NEGATIVE SCORE','POLARITY SCORE','SUBJECTIVITY SCORE','AVG SENTENCE LENGTH','PERCENTAGE OF COMPLEX WORDS','FOG INDEX','AVG NUMBER OF WORDS PER SENTENCE',
                   'COMPLEX WORD COUNT','WORD COUNT','SYLLABLE PER WORD','PERSONAL PRONOUNS','AVG WORD LENGTH']

df = df.drop(columns=columns_to_drop)

# %%
df.columns
# Out:
# Index(['URL_ID', 'URL'], dtype='object')

# %%
df_scores.columns
# Out:
# Index(['URL_ID', 'POSITIVE SCORE', 'NEGATIVE SCORE', 'POLARITY SCORE',
#        'SUBJECTIVITY SCORE', 'AVG SENTENCE LENGTH',
#        'PERCENTAGE OF COMPLEX WORDS', 'FOG INDEX',
#        'AVG NUMBER OF WORDS PER SENTENCE', 'SYLLABLE PER WORD',
#        'PERSONAL PRONOUNS', 'AVG WORD LENGTH', 'COMPLEX WORD COUNT',
#        'WORD COUNT'],
#       dtype='object')

# %%
data = pd.merge(df, df_scores, on='URL_ID', how='inner')

# %%
data.columns
# Out:
# Index(['URL_ID', 'URL', 'POSITIVE SCORE', 'NEGATIVE SCORE', 'POLARITY SCORE',
#        'SUBJECTIVITY SCORE', 'AVG SENTENCE LENGTH',
#        'PERCENTAGE OF COMPLEX WORDS', 'FOG INDEX',
#        'AVG NUMBER OF WORDS PER SENTENCE', 'SYLLABLE PER WORD',
#        'PERSONAL PRONOUNS', 'AVG WORD LENGTH', 'COMPLEX WORD COUNT',
#        'WORD COUNT'],
#       dtype='object')

# %% [markdown]
# ***code to save the data frame into an excel file***

# %%
excel_file_path = 'D:\internship\Output Data Structure 2.xlsx'
data.to_excel(excel_file_path, index=False)
print(f"DataFrame has been saved to {excel_file_path}")
# Out:
# DataFrame has been saved to D:\internship\Output Data Structure 2.xlsx
